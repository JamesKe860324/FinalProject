# %%
import pandas as pd

# %%
data = pd.read_csv('toTGOS/final_table_include_floor.csv', encoding = 'ANSI')
data
# Out:
# e:\program\python\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (8,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              X 鄉鎮市區                 完整地址          交易標的   建築完成年月  finish_year  \
# 0            1  八里區  新北市八里區龍米路一段３０８號８樓之１     房地(土地+建物)  1011119          101
# 1            2  八里區       新北市八里區商港路16號2樓     房地(土地+建物)   820504           82
# 2            3  八里區   新北市八里區龍米路１段448號24樓  房地(土地+建物)+車位   850923           85
# 3            4  八里區      新北市八里區下罟子54之12號     房地(土地+建物)   700820           70
# 4            5  八里區      新北市八里區下罟子５４之１４號     房地(土地+建物)   700820           70
# ...        ...  ...                  ...           ...      ...          ...
# 367188  367189  鶯歌區       新北市鶯歌區鶯歌路98號9樓  房地(土地+建物)+車位  1080604          108
# 367189  367190  鶯歌區       新北市鶯歌區鶯歌路９８號八樓  房地(土地+建物)+車位  1080604          108
# ...

# %%
data = data.drop("電梯", axis = 1)

# %%
data.head()
# Out:
#    X 鄉鎮市區                 完整地址          交易標的   建築完成年月  finish_year    交易年月日  \
# 0  1  八里區  新北市八里區龍米路一段３０８號８樓之１     房地(土地+建物)  1011119          101  1020626
# 1  2  八里區       新北市八里區商港路16號2樓     房地(土地+建物)   820504           82  1011122
# 2  3  八里區   新北市八里區龍米路１段448號24樓  房地(土地+建物)+車位   850923           85  1020204
# 3  4  八里區      新北市八里區下罟子54之12號     房地(土地+建物)   700820           70  1020126
# 4  5  八里區      新北市八里區下罟子５４之１４號     房地(土地+建物)   700820           70  1040629
#
#    trade_year       總價元 單價元平方公尺  ... 建物現況格局.隔間 有無管理組織 主要用途  min_inci  \
# 0         102   7250000  72,146  ...         無      有  住家用  8.561386
# 1         101   3580000  35,071  ...         有      有  住家用  3.216651
# 2         102  13900000  70,846  ...         有      有  住家用  8.482000
# 3         102   8100000  40,492  ...         有      無  住商用  2.203121
# 4         104   7150000  39,351  ...         有      無  住商用  2.221027
#
#     min_hos   min_mrt  min_mart   min_gas min_school  min_park
# ...

# %%
data.loc[:, '有無管理組織'] = data.loc[:, '有無管理組織'].map({"有":1, "無":0})

# %%
data.head()

# %%
data.loc[:, '建物現況格局.隔間'] = data.loc[:, '建物現況格局.隔間'].map({"有":1, "無":0})

# %%
data.columns
# Out:
# Index(['X', '鄉鎮市區', '完整地址', '交易標的', '建築完成年月', 'finish_year', '交易年月日',
#        'trade_year', '總價元', '單價元平方公尺', '移轉層次', 'floor', '總樓層數', '建物型態',
#        '建物現況格局.房', '建物現況格局.廳', '建物現況格局.衛', '建物現況格局.隔間', '有無管理組織', '主要用途',
#        'min_inci', 'min_hos', 'min_mrt', 'min_mart', 'min_gas', 'min_school',
#        'min_park'],
#       dtype='object')

# %%
# 0 -> 住宅大樓(11層含以上有電梯)
# 1 -> 公寓(5樓含以下無電梯)
# 2 -> 華廈(10層含以下有電梯)
# 3 -> 套房(1房1廳1衛)
# 4 -> 透天厝
data['建物型態'].unique()
# Out:
# array(['住宅大樓(11層含以上有電梯)', '透天厝', '公寓(5樓含以下無電梯)', '華廈(10層含以下有電梯)',
#        '套房(1房1廳1衛)', '其他'], dtype=object)

# %%
data[data.loc[:, '建物型態'].str.contains('透天厝')]
# Out:
#              X 鄉鎮市區               完整地址          交易標的  建築完成年月  finish_year  \
# 3            4  八里區    新北市八里區下罟子54之12號     房地(土地+建物)  700820           70
# 4            5  八里區    新北市八里區下罟子５４之１４號     房地(土地+建物)  700820           70
# 6            7  八里區    新北市八里區下罟子５７之２１號     房地(土地+建物)  690325           69
# 7            8  八里區    新北市八里區下罟子５７之２３號     房地(土地+建物)  690325           69
# 8            9  八里區    新北市八里區下罟子５７之２４號     房地(土地+建物)  690325           69
# ...        ...  ...                ...           ...     ...          ...
# 366963  366964  鶯歌區  新北市鶯歌區鶯桃路９４巷１５弄８號     房地(土地+建物)  860409           86
# 366970  366971  鶯歌區     新北市鶯歌區鶯桃路９７之５號     房地(土地+建物)  800615           80
# 367012  367013  鶯歌區     新北市鶯歌區鶯桃路永富巷１號  房地(土地+建物)+車位  870210           87
# 367013  367014  鶯歌區     新北市鶯歌區鶯桃路永富巷１號  房地(土地+建物)+車位  870210           87
# 367018  367019  鶯歌區    新北市鶯歌區鶯桃路94巷25號     房地(土地+建物)  890425           89
#
#           交易年月日  trade_year       總價元 單價元平方公尺  ... 建物現況格局.隔間 有無管理組織     主要用途  \
# ...

# %%
test = data.loc[:, "單價元平方公尺"].str.split(',')

# %%
test

# %%
data.loc[3,]

# %%
house = data[data.loc[:, '主要用途'] == "住家用"]

# %%
house.loc[:, '建物現況格局.廳'].value_counts()

# %%
house[house.loc[:, "建物現況格局.廳"] == 21]

# %%
house[house.loc[:, '完整地址'] == "新北市中和區景平路323號4樓之10"]

# %%
house.loc[88869, '單價元平方公尺']
