# %%
import pandas as pd

# %%
df = pd.read_csv('toTGOS/realEstate_二篩 (remove).csv')
# Out:
# e:\program\python\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (3,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#        鄉鎮市區                 完整地址          交易標的   建築完成年月    交易年月日      總價元   \
# 0       八里區  新北市八里區龍米路一段３０８號８樓之１     房地(土地+建物)  1011119  1020626   7250000
# 1       八里區       新北市八里區商港路16號2樓     房地(土地+建物)   820504  1011122   3580000
# 2       八里區   新北市八里區龍米路１段448號24樓  房地(土地+建物)+車位   850923  1020204  13900000
# 3       八里區      新北市八里區下罟子54之12號     房地(土地+建物)   700820  1020126   8100000
# 4       八里區      新北市八里區下罟子５４之１４號     房地(土地+建物)   700820  1040629   7150000
# ...     ...                  ...           ...      ...      ...       ...
# 368159  鶯歌區       新北市鶯歌區鶯歌路98號9樓  房地(土地+建物)+車位  1080604  1070814   9530000
# 368160  鶯歌區       新北市鶯歌區鶯歌路９８號八樓  房地(土地+建物)+車位  1080604  1071127   9350000
# 368161  鶯歌區      新北市鶯歌區鶯歌路９８號十三樓  房地(土地+建物)+車位  1080604  1080718   9540000
# 368162  鶯歌區       新北市鶯歌區鶯歌路９８號十樓  房地(土地+建物)+車位  1080604  1080826  10550000
# 368163  鶯歌區       新北市鶯歌區鶯歌路９８號三樓  房地(土地+建物)+車位  1080604  1080821   9200000
#
# ...

# %%
# df['Address'] = df['Address'].str.slice(0,5)+ "區" + df['Address'].str.slice(6)

# %%
# df = df.drop([1,2], axis = 1)

# %%
# df = df.rename(columns = {0 : "Address" })
# df['Address'] = df['Address'].str.slice(6)

# %% [markdown]
# # 移除含有重複地址欄位

# %%
data1 = df['完整地址'].str.contains('，')
sum(data1)
# Out:
# 166

# %%
df = df[data1 == False]

# %%
df
# Out:
#        鄉鎮市區                 完整地址          交易標的   建築完成年月    交易年月日      總價元   \
# 0       八里區  新北市八里區龍米路一段３０８號８樓之１     房地(土地+建物)  1011119  1020626   7250000
# 1       八里區       新北市八里區商港路16號2樓     房地(土地+建物)   820504  1011122   3580000
# 2       八里區   新北市八里區龍米路１段448號24樓  房地(土地+建物)+車位   850923  1020204  13900000
# 3       八里區      新北市八里區下罟子54之12號     房地(土地+建物)   700820  1020126   8100000
# 4       八里區      新北市八里區下罟子５４之１４號     房地(土地+建物)   700820  1040629   7150000
# ...     ...                  ...           ...      ...      ...       ...
# 368159  鶯歌區       新北市鶯歌區鶯歌路98號9樓  房地(土地+建物)+車位  1080604  1070814   9530000
# 368160  鶯歌區       新北市鶯歌區鶯歌路９８號八樓  房地(土地+建物)+車位  1080604  1071127   9350000
# 368161  鶯歌區      新北市鶯歌區鶯歌路９８號十三樓  房地(土地+建物)+車位  1080604  1080718   9540000
# 368162  鶯歌區       新北市鶯歌區鶯歌路９８號十樓  房地(土地+建物)+車位  1080604  1080826  10550000
# 368163  鶯歌區       新北市鶯歌區鶯歌路９８號三樓  房地(土地+建物)+車位  1080604  1080821   9200000
#
# ...

# %%
data2 = df['完整地址'].str.contains('/')
sum(data2)
# Out:
# 6

# %%
df = df[data2 == False]

# %%
df
# Out:
#        鄉鎮市區                 完整地址          交易標的   建築完成年月    交易年月日      總價元   \
# 0       八里區  新北市八里區龍米路一段３０８號８樓之１     房地(土地+建物)  1011119  1020626   7250000
# 1       八里區       新北市八里區商港路16號2樓     房地(土地+建物)   820504  1011122   3580000
# 2       八里區   新北市八里區龍米路１段448號24樓  房地(土地+建物)+車位   850923  1020204  13900000
# 3       八里區      新北市八里區下罟子54之12號     房地(土地+建物)   700820  1020126   8100000
# 4       八里區      新北市八里區下罟子５４之１４號     房地(土地+建物)   700820  1040629   7150000
# ...     ...                  ...           ...      ...      ...       ...
# 368159  鶯歌區       新北市鶯歌區鶯歌路98號9樓  房地(土地+建物)+車位  1080604  1070814   9530000
# 368160  鶯歌區       新北市鶯歌區鶯歌路９８號八樓  房地(土地+建物)+車位  1080604  1071127   9350000
# 368161  鶯歌區      新北市鶯歌區鶯歌路９８號十三樓  房地(土地+建物)+車位  1080604  1080718   9540000
# 368162  鶯歌區       新北市鶯歌區鶯歌路９８號十樓  房地(土地+建物)+車位  1080604  1080826  10550000
# 368163  鶯歌區       新北市鶯歌區鶯歌路９８號三樓  房地(土地+建物)+車位  1080604  1080821   9200000
#
# ...

# %%
data3 = df['完整地址'].str.contains('及')
sum(data3)
# Out:
# 558

# %%
df = df[data3 == False]

# %%
df
# Out:
#        鄉鎮市區                 完整地址          交易標的   建築完成年月    交易年月日      總價元   \
# 0       八里區  新北市八里區龍米路一段３０８號８樓之１     房地(土地+建物)  1011119  1020626   7250000
# 1       八里區       新北市八里區商港路16號2樓     房地(土地+建物)   820504  1011122   3580000
# 2       八里區   新北市八里區龍米路１段448號24樓  房地(土地+建物)+車位   850923  1020204  13900000
# 3       八里區      新北市八里區下罟子54之12號     房地(土地+建物)   700820  1020126   8100000
# 4       八里區      新北市八里區下罟子５４之１４號     房地(土地+建物)   700820  1040629   7150000
# ...     ...                  ...           ...      ...      ...       ...
# 368159  鶯歌區       新北市鶯歌區鶯歌路98號9樓  房地(土地+建物)+車位  1080604  1070814   9530000
# 368160  鶯歌區       新北市鶯歌區鶯歌路９８號八樓  房地(土地+建物)+車位  1080604  1071127   9350000
# 368161  鶯歌區      新北市鶯歌區鶯歌路９８號十三樓  房地(土地+建物)+車位  1080604  1080718   9540000
# 368162  鶯歌區       新北市鶯歌區鶯歌路９８號十樓  房地(土地+建物)+車位  1080604  1080826  10550000
# 368163  鶯歌區       新北市鶯歌區鶯歌路９８號三樓  房地(土地+建物)+車位  1080604  1080821   9200000
#
# ...

# %%
data4 = df['完整地址'].str.contains('、')
sum(data4)
# Out:
# 241

# %%
df = df[data4 == False]

# %%
df
# Out:
#        鄉鎮市區                 完整地址          交易標的   建築完成年月    交易年月日      總價元   \
# 0       八里區  新北市八里區龍米路一段３０８號８樓之１     房地(土地+建物)  1011119  1020626   7250000
# 1       八里區       新北市八里區商港路16號2樓     房地(土地+建物)   820504  1011122   3580000
# 2       八里區   新北市八里區龍米路１段448號24樓  房地(土地+建物)+車位   850923  1020204  13900000
# 3       八里區      新北市八里區下罟子54之12號     房地(土地+建物)   700820  1020126   8100000
# 4       八里區      新北市八里區下罟子５４之１４號     房地(土地+建物)   700820  1040629   7150000
# ...     ...                  ...           ...      ...      ...       ...
# 368159  鶯歌區       新北市鶯歌區鶯歌路98號9樓  房地(土地+建物)+車位  1080604  1070814   9530000
# 368160  鶯歌區       新北市鶯歌區鶯歌路９８號八樓  房地(土地+建物)+車位  1080604  1071127   9350000
# 368161  鶯歌區      新北市鶯歌區鶯歌路９８號十三樓  房地(土地+建物)+車位  1080604  1080718   9540000
# 368162  鶯歌區       新北市鶯歌區鶯歌路９８號十樓  房地(土地+建物)+車位  1080604  1080826  10550000
# 368163  鶯歌區       新北市鶯歌區鶯歌路９８號三樓  房地(土地+建物)+車位  1080604  1080821   9200000
#
# ...

# %%
df.to_csv('realEstate_toTGOS_fullTable.csv', index = False, encoding = 'utf-8')

# %% [markdown]
# # 分割成37份

# %%
# split data into 37 pices
for i in range(37) :
    newdf = df.iloc[i*10000: (i+1)*10000, :]
    newdf['id'] = range(1,len(newdf)+1)
    newdf.to_csv(f'toTGOS/data/part{i+1}.csv', index = False, encoding = 'ANSI')
# Out:
# e:\program\python\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
data = pd.DataFrame({
    "id" : range(1,len(df)+1),
    'Address' : df['完整地址'],
    "Response_Address" : "",
    "Response_X" : "",
    "Response_Y" : "" 
})

# %%
data
# Out:
#             id              Address Response_Address Response_X Response_Y
# 0            1  新北市八里區龍米路一段３０８號８樓之１
# 1            2       新北市八里區商港路16號2樓
# 2            3   新北市八里區龍米路１段448號24樓
# 3            4      新北市八里區下罟子54之12號
# 4            5      新北市八里區下罟子５４之１４號
# ...        ...                  ...              ...        ...        ...
# 367188  367189       新北市鶯歌區鶯歌路98號9樓
# 367189  367190       新北市鶯歌區鶯歌路９８號八樓
# 367190  367191      新北市鶯歌區鶯歌路９８號十三樓
# 367191  367192       新北市鶯歌區鶯歌路９８號十樓
# 367192  367193       新北市鶯歌區鶯歌路９８號三樓
#
# [367193 rows x 5 columns]

# %%
data.to_csv('realEstate_toTGOS.csv', index = False, encoding = 'ANSI')

# %% [markdown]
# ## 篩測試資料先進spark

# %%
finish = pd.read_csv('Address_Finish_part4_1_10000.csv')
finish

# %%
finish1 = finish[0:10000]
finish1

# %%
# 可以找出Response_X中沒有nan的部分
finish1.iloc[:, 3][finish1.iloc[:, 3].isnull() == False]

# %%
# 直接利用notnull()篩選出沒有nan的列
finish1_not_null = finish1[finish['Response_X'].notnull()]

# %%
# 重製index
finish1_not_null_reindex = finish1_not_null.reset_index(drop = True)

# %%
finish1_not_null_reindex

# %%
finish1_not_null_reindex['Response_X'] = finish1_not_null_reindex['Response_X'].str.slice(0,10)
finish1_not_null_reindex['Response_Y'] = finish1_not_null_reindex['Response_Y'].str.slice(0,10)

# %%
finish1_not_null_reindex.to_csv('test.csv', index = False)

# %% [markdown]
# # 修改宇軒的資料改成我的python程式可以跑的格式

# %%
df = pd.read_csv('toTGOS/part1(with latlong).csv', header = None, encoding = 'utf-8')

# %%
df

# %%
df[0] = df[0].str.slice(6)

# %%
df.drop(columns = 1)
split = df[2].str.split(",")

# %%
df['Response_Address'] = ""
df['Response_X'] = ""
df['Response_Y'] = ""

# %%
for i in range(len(df)) :
    df.iloc[i,5] = split[i][0]
    df.iloc[i,4] = split[i][1]

# %%
df.drop(columns = [1,2])

# %%
df.rename(columns = { 0 : 'Address'})

# %%
df = df.drop(columns = 1)
df = df.drop(columns = 2)

# %%
df = df.rename(columns = { 0 : 'Address'})

# %%
df.insert(0, "id", range(len(df)))

# %%
df

# %%
df.to_csv('part1_min.csv', index = False)
