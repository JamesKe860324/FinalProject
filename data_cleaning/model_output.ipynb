# %%
import pandas as pd

# %%
pd.set_option("display.max_columns", None)

# %%
data = pd.read_csv('../data/data/table/table_for_model_no_outlier_0905.csv')
data.shape
# Out:
# (224868, 22)

# %%
data.columns
# Out:
# Index(['id', 'section', 'parking_space', 'age', 'status', 'unit_price_ping',
#        'area', 'floor', 'type', 'room', 'lr', 'bath', 'partition', 'mgmt',
#        'min_inci', 'min_hos', 'min_mrt', 'min_mart', 'min_gas', 'min_school',
#        'min_park', 'yearMonth'],
#       dtype='object')

# %%
data
# Out:
#             id  section  parking_space  age  status  unit_price_ping  \
# 0         2544        1              1   -3       1      351799.9302
# 1         2576        1              0   -3       1      311984.8750
# 2        10229        3              1   -2       1      366649.5838
# 3        10230        3              1   -2       1      369783.4822
# 4        10232        3              1   -2       1      388586.8726
# ...        ...      ...            ...  ...     ...              ...
# 224863  359934       28              1   25       0      152635.4000
# 224864  360370       28              0   40       0      163009.0000
# 224865  361210       28              0   37       0      293892.2000
# 224866  363211       28              1   13       0      276292.2000
# 224867  364916       28              0   40       0      297819.5000
#
#              area  floor  type  room  lr  bath  partition  mgmt  min_inci  \
# ...

# %% [markdown]
# # filter general_model_full

# %%
general_model_full = data.drop(columns = {'floor', 'yearMonth'})

# %%
general_model_full.columns
# Out:
# Index(['id', 'section', 'parking_space', 'age', 'status', 'unit_price_ping',
#        'area', 'type', 'room', 'lr', 'bath', 'partition', 'mgmt', 'min_inci',
#        'min_hos', 'min_mrt', 'min_mart', 'min_gas', 'min_school', 'min_park'],
#       dtype='object')

# %%
general_model_full
# Out:
#             id  section  parking_space  age  status  unit_price_ping  \
# 0         2544        1              1   -3       1      351799.9302
# 1         2576        1              0   -3       1      311984.8750
# 2        10229        3              1   -2       1      366649.5838
# 3        10230        3              1   -2       1      369783.4822
# 4        10232        3              1   -2       1      388586.8726
# ...        ...      ...            ...  ...     ...              ...
# 224863  359934       28              1   25       0      152635.4000
# 224864  360370       28              0   40       0      163009.0000
# 224865  361210       28              0   37       0      293892.2000
# 224866  363211       28              1   13       0      276292.2000
# 224867  364916       28              0   40       0      297819.5000
#
#              area  type  room  lr  bath  partition  mgmt  min_inci   min_hos  \
# ...

# %%
general_model_full.to_csv('model_data/general_model_full/general_model_full.csv', index = False, encoding = 'utf-8')

# %% [markdown]
# ### filter general_model_items

# %%
general_model_items = general_model_full.iloc[:,0:13]

# %%
general_model_items
# Out:
#             id  section  parking_space  age  status  unit_price_ping  \
# 0         2544        1              1   -3       1      351799.9302
# 1         2576        1              0   -3       1      311984.8750
# 2        10229        3              1   -2       1      366649.5838
# 3        10230        3              1   -2       1      369783.4822
# 4        10232        3              1   -2       1      388586.8726
# ...        ...      ...            ...  ...     ...              ...
# 224863  359934       28              1   25       0      152635.4000
# 224864  360370       28              0   40       0      163009.0000
# 224865  361210       28              0   37       0      293892.2000
# 224866  363211       28              1   13       0      276292.2000
# 224867  364916       28              0   40       0      297819.5000
#
#              area  type  room  lr  bath  partition  mgmt
# 0       34.423129     0     2   1     1          1     1
# ...

# %%
general_model_items.to_csv('model_data/general_model_full/general_model_items.csv', index = False, encoding = 'utf-8')

# %% [markdown]
# ### filter general_model_functional

# %%
general_model_functional = pd.concat([general_model_full.loc[:, 'id'], general_model_full.iloc[:, 13:], general_model_full.loc[:, 'unit_price_ping']],  axis = 1)

# %%
general_model_functional
# Out:
#             id  min_inci   min_hos   min_mrt  min_mart   min_gas  min_school  \
# 0         2544  8.245495  1.521758  1.225684  1.349076  0.114277    0.707744
# 1         2576  8.246467  1.522292  1.227816  1.351557  0.108192    0.714008
# 2        10229  8.810514  0.979776  0.816443  0.286394  0.924007    0.315363
# 3        10230  8.810514  0.979776  0.816443  0.286394  0.924007    0.315363
# 4        10232  8.810514  0.979776  0.816443  0.286394  0.924007    0.315363
# ...        ...       ...       ...       ...       ...       ...         ...
# 224863  359934  2.958557  2.687204  7.005375  0.714222  0.427335    0.791303
# 224864  360370  2.886246  2.345481  6.835302  0.410173  0.090360    0.544824
# 224865  361210  4.695241  1.061871  8.887293  2.493326  0.402268    0.199779
# 224866  363211  2.695925  2.136047  6.579679  0.422481  0.199669    0.320183
# 224867  364916  3.366807  2.253049  7.234868  0.340384  0.408499    0.318492
#
#         min_park  unit_price_ping
# ...

# %%
general_model_functional.to_csv('model_data/general_model_full/general_model_functional.csv', index = False, encoding = 'utf-8')

# %% [markdown]
# # filter general_model_section

# %%
general_model_section = data.drop(columns = {'floor', 'yearMonth'})

# %%
general_model_section.columns
# Out:
# Index(['id', 'section', 'parking_space', 'age', 'status', 'unit_price_ping',
#        'area', 'type', 'room', 'lr', 'bath', 'partition', 'mgmt', 'min_inci',
#        'min_hos', 'min_mrt', 'min_mart', 'min_gas', 'min_school', 'min_park'],
#       dtype='object')

# %%
groupby_section = general_model_section.groupby('section')

# %%
groupby_section.size()
# Out:
# section
# 1      3530
# 2      2642
# 3     19431
# 4     10355
# 5      6103
# 6     11502
# 7     19777
# 8     18828
# 9      8572
# 10     3218
# 12       53
# 13       39
# 14    19854
# 15      704
# 16      877
# 18     7187
# 19     3227
# 20    16609
# 21       61
# 22    39950
# 23     1304
# 24    21628
# 25      474
# 26     6447
# 27       31
# 28     2465
# dtype: int64

# %%
for i in range(1,29) :
    if i not in (11,17) :
        section = groupby_section.get_group(i)
        section = section.drop('section', axis = 1)
        section.to_csv(f'model_data/general_model_section/general_model_section_{i}.csv', index = False, encoding = 'utf-8')
    else :
        continue

# %% [markdown]
# # filter general_model_type

# %%
general_model_type = data.drop('yearMonth', axis = 1)

# %%
general_model_type
# Out:
#             id  section  parking_space  age  status  unit_price_ping  \
# 0         2544        1              1   -3       1      351799.9302
# 1         2576        1              0   -3       1      311984.8750
# 2        10229        3              1   -2       1      366649.5838
# 3        10230        3              1   -2       1      369783.4822
# 4        10232        3              1   -2       1      388586.8726
# ...        ...      ...            ...  ...     ...              ...
# 224863  359934       28              1   25       0      152635.4000
# 224864  360370       28              0   40       0      163009.0000
# 224865  361210       28              0   37       0      293892.2000
# 224866  363211       28              1   13       0      276292.2000
# 224867  364916       28              0   40       0      297819.5000
#
#              area  floor  type  room  lr  bath  partition  mgmt  min_inci  \
# ...

# %%
groupby_type = general_model_type.groupby('type')

# %%
groupby_type.size()
# Out:
# type
# 0    112750
# 1     59991
# 2      5862
# 3     33969
# 4     12296
# dtype: int64

# %%
for i in range(0, 5):
    types = groupby_type.get_group(i)
    types = types.drop('type', axis = 1)
    types.to_csv(f'model_data/general_model_type/general_model_type_{i}.csv', index = False, encoding = 'utf-8')

# %% [markdown]
# # filter general_model_status

# %%
general_model_status_0 = data[data['status'] == 0]

# %%
general_model_status_0 = general_model_status_0.drop('yearMonth', axis = 1)

# %%
general_model_status_0.to_csv('../model_data/model_data/general_model_status/genaral_model_status_0.csv', index = False, encoding = 'utf-8')

# %%
general_model_status_1 = data[data['status'] == 1]

# %%
general_model_status_1 = general_model_status_1.drop('yearMonth', axis = 1)

# %%
general_model_status_1.to_csv('../model_data/model_data/general_model_status/genaral_model_status_1.csv', index = False, encoding = 'utf-8')

# %% [markdown]
# # filter time_model_full

# %%
time_model_full = data.drop('floor', axis = 1)

# %%
time_model_full
# Out:
#             id  section  parking_space  age  status  unit_price_ping  \
# 0         2544        1              1   -3       1      351799.9302
# 1         2576        1              0   -3       1      311984.8750
# 2        10229        3              1   -2       1      366649.5838
# 3        10230        3              1   -2       1      369783.4822
# 4        10232        3              1   -2       1      388586.8726
# ...        ...      ...            ...  ...     ...              ...
# 224863  359934       28              1   25       0      152635.4000
# 224864  360370       28              0   40       0      163009.0000
# 224865  361210       28              0   37       0      293892.2000
# 224866  363211       28              1   13       0      276292.2000
# 224867  364916       28              0   40       0      297819.5000
#
#              area  type  room  lr  bath  partition  mgmt  min_inci   min_hos  \
# ...

# %%
time_model_full.to_csv('../model_data/model_data/time_model_full/time_model_full.csv', index = False, encoding = 'utf-8')

# %% [markdown]
# ### filter time_model_items

# %%
year_month = data['yearMonth']

# %%
time_model_items = time_model_full.iloc[:, 0:13]

# %%
time_model_items
# Out:
#             id  section  parking_space  age  status  unit_price_ping  \
# 0         2544        1              1   -3       1      351799.9302
# 1         2576        1              0   -3       1      311984.8750
# 2        10229        3              1   -2       1      366649.5838
# 3        10230        3              1   -2       1      369783.4822
# 4        10232        3              1   -2       1      388586.8726
# ...        ...      ...            ...  ...     ...              ...
# 224863  359934       28              1   25       0      152635.4000
# 224864  360370       28              0   40       0      163009.0000
# 224865  361210       28              0   37       0      293892.2000
# 224866  363211       28              1   13       0      276292.2000
# 224867  364916       28              0   40       0      297819.5000
#
#              area  type  room  lr  bath  partition  mgmt
# 0       34.423129     0     2   1     1          1     1
# ...

# %%
time_model_items = pd.concat([time_model_items, year_month], axis = 1)

# %%
time_model_items
# Out:
#             id  section  parking_space  age  status  unit_price_ping  \
# 0         2544        1              1   -3       1      351799.9302
# 1         2576        1              0   -3       1      311984.8750
# 2        10229        3              1   -2       1      366649.5838
# 3        10230        3              1   -2       1      369783.4822
# 4        10232        3              1   -2       1      388586.8726
# ...        ...      ...            ...  ...     ...              ...
# 224863  359934       28              1   25       0      152635.4000
# 224864  360370       28              0   40       0      163009.0000
# 224865  361210       28              0   37       0      293892.2000
# 224866  363211       28              1   13       0      276292.2000
# 224867  364916       28              0   40       0      297819.5000
#
#              area  type  room  lr  bath  partition  mgmt yearMonth
# 0       34.423129     0     2   1     1          1     1    100-07
# ...

# %%
time_model_items.to_csv('../model_data/model_data/time_model_full/time_model_items.csv', index = False, encoding = 'utf-8')

# %% [markdown]
# ### filter time_model_functional

# %%
time_model_functional = pd.concat([time_model_full.loc[:, 'id'], time_model_full.iloc[:, 13:], time_model_full.loc[:, "unit_price_ping"]], axis = 1)

# %%
time_model_functional
# Out:
#             id  min_inci   min_hos   min_mrt  min_mart   min_gas  min_school  \
# 0         2544  8.245495  1.521758  1.225684  1.349076  0.114277    0.707744
# 1         2576  8.246467  1.522292  1.227816  1.351557  0.108192    0.714008
# 2        10229  8.810514  0.979776  0.816443  0.286394  0.924007    0.315363
# 3        10230  8.810514  0.979776  0.816443  0.286394  0.924007    0.315363
# 4        10232  8.810514  0.979776  0.816443  0.286394  0.924007    0.315363
# ...        ...       ...       ...       ...       ...       ...         ...
# 224863  359934  2.958557  2.687204  7.005375  0.714222  0.427335    0.791303
# 224864  360370  2.886246  2.345481  6.835302  0.410173  0.090360    0.544824
# 224865  361210  4.695241  1.061871  8.887293  2.493326  0.402268    0.199779
# 224866  363211  2.695925  2.136047  6.579679  0.422481  0.199669    0.320183
# 224867  364916  3.366807  2.253049  7.234868  0.340384  0.408499    0.318492
#
#         min_park yearMonth  unit_price_ping
# ...

# %%
time_model_functional.to_csv('../model_data/model_data/time_model_full/time_model_functional.csv', index = False, encoding = 'utf-8')

# %% [markdown]
# # filter time_model_section

# %%
time_model_section = data.drop(columns = {'floor'})

# %%
time_model_section.columns
# Out:
# Index(['id', 'section', 'parking_space', 'age', 'status', 'unit_price_ping',
#        'area', 'type', 'room', 'lr', 'bath', 'partition', 'mgmt', 'min_inci',
#        'min_hos', 'min_mrt', 'min_mart', 'min_gas', 'min_school', 'min_park',
#        'yearMonth'],
#       dtype='object')

# %%
time_model_section.shape
# Out:
# (224868, 21)

# %%
groupby_time_section = time_model_section.groupby('section')

# %%
groupby_time_section.size()
# Out:
# section
# 1      3530
# 2      2642
# 3     19431
# 4     10355
# 5      6103
# 6     11502
# 7     19777
# 8     18828
# 9      8572
# 10     3218
# 12       53
# 13       39
# 14    19854
# 15      704
# 16      877
# 18     7187
# 19     3227
# 20    16609
# 21       61
# 22    39950
# 23     1304
# 24    21628
# 25      474
# 26     6447
# 27       31
# 28     2465
# dtype: int64

# %%
for i in range(1,29) :
    if i not in (11,17) :
        section = groupby_time_section.get_group(i)
        section = section.drop('section', axis = 1)
        section.to_csv(f'../model_data/model_data/time_model_section/time_model_section_{i}.csv', index = False, encoding = 'utf-8')
    else :
        continue

# %% [markdown]
# # filter time_model_type

# %%
time_model_type = data

# %%
time_model_type
# Out:
#             id  section  parking_space  age  status  unit_price_ping  \
# 0         2544        1              1   -3       1      351799.9302
# 1         2576        1              0   -3       1      311984.8750
# 2        10229        3              1   -2       1      366649.5838
# 3        10230        3              1   -2       1      369783.4822
# 4        10232        3              1   -2       1      388586.8726
# ...        ...      ...            ...  ...     ...              ...
# 224863  359934       28              1   25       0      152635.4000
# 224864  360370       28              0   40       0      163009.0000
# 224865  361210       28              0   37       0      293892.2000
# 224866  363211       28              1   13       0      276292.2000
# 224867  364916       28              0   40       0      297819.5000
#
#              area  floor  type  room  lr  bath  partition  mgmt  min_inci  \
# ...

# %%
groupby_time_type = time_model_type.groupby('type')

# %%
groupby_time_type.size()
# Out:
# type
# 0    112750
# 1     59991
# 2      5862
# 3     33969
# 4     12296
# dtype: int64

# %%
for i in range(0, 5):
    types = groupby_time_type.get_group(i)
    types = types.drop('type', axis = 1)
    types.to_csv(f'../model_data/model_data/time_model_type/general_model_type_{i}.csv', index = False, encoding = 'utf-8')

# %% [markdown]
# # filter time_model_status

# %%
time_model_status_0 = data[data['status'] == 0]

# %%
time_model_status_0
# Out:
#             id  section  parking_space  age  status  unit_price_ping  \
# 53       23034        3              0   18       0      337945.3224
# 96       56265        6              0   30       0      210172.8466
# 97       60623        6              0   21       0      228096.8942
# 98       63198        6              0   31       0      221012.5648
# 199      78232        8              0   37       0      234496.9230
# ...        ...      ...            ...  ...     ...              ...
# 224863  359934       28              1   25       0      152635.4000
# 224864  360370       28              0   40       0      163009.0000
# 224865  361210       28              0   37       0      293892.2000
# 224866  363211       28              1   13       0      276292.2000
# 224867  364916       28              0   40       0      297819.5000
#
#              area  floor  type  room  lr  bath  partition  mgmt  min_inci  \
# ...

# %%
time_model_status_0.to_csv('../model_data/model_data/time_model_status/time_model_status_0.csv', index = False, encoding = 'utf-8')

# %%
time_model_status_1 = data[data['status'] == 1]

# %%
time_model_status_1
# Out:
#             id  section  parking_space  age  status  unit_price_ping  \
# 0         2544        1              1   -3       1      351799.9302
# 1         2576        1              0   -3       1      311984.8750
# 2        10229        3              1   -2       1      366649.5838
# 3        10230        3              1   -2       1      369783.4822
# 4        10232        3              1   -2       1      388586.8726
# ...        ...      ...            ...  ...     ...              ...
# 223548  245301       22              1    1       1      279842.6000
# 223549  245308       22              1    1       1      288034.4000
# 223550  245319       22              1    1       1      273412.8000
# 223556  245346       22              1    1       1      249654.0000
# 224786  363331       28              0    1       1      229164.7000
#
#              area  floor  type  room  lr  bath  partition  mgmt  min_inci  \
# ...

# %%
time_model_status_1.to_csv('../model_data/model_data/time_model_status/time_model_status_1.csv', index = False, encoding = 'utf-8')
