# %%
import pandas as pd

# %%
data = pd.read_csv('general_model_full.csv')
data
# Out:
#             id  section  parking_space  construction_time  trade_time  age  \
# 0            2        1              0             820504     1011122   19
# 1            3        1              1             850923     1020204   17
# 2            6        1              0             700820     1031209   33
# 3            7        1              0             690325     1040913   35
# 4            8        1              0             690325     1090923   40
# ...        ...      ...            ...                ...         ...  ...
# 233663  367014       28              1             870210     1040729   17
# 233664  367015       28              1             870210     1100329   23
# 233665  367016       28              1             870210     1090608   22
# 233666  367017       28              0             780615     1020804   24
# 233667  367018       28              0             860625     1020618   16
#
#         unit_price_ping       area trasaction_floor total_floor  ...  \
# 0           115937.7118  30.878789               二層         十三層  ...
# 1           234202.7068  59.350563             二十四層         三十層  ...
# 2           103878.1534  24.066766               二層          二層  ...
# 3           110000.4950  73.568000                全          二層  ...
# 4            99940.9456  80.047632                全          二層  ...
# ...                 ...        ...              ...         ...  ...
# 233663       74909.4280  76.092230                全          四層  ...
# 233664      209769.5390  69.123790         二層，三層，四層          四層  ...
# 233665      210586.0716  68.285930         二層，三層，四層          四層  ...
# 233666      114698.0368  36.618050               五層          五層  ...
# 233667      106949.2416  18.700540               五層          七層  ...
#
#        partition  mgmt  min_inci   min_hos   min_mrt  min_mart   min_gas  \
# 0              1     1  3.216651  2.360415  6.347960  0.421408  0.259130
# 1              1     1  8.482000  1.320465  0.893130  0.957701  0.794212
# 2              1     0  2.242399  3.157690  7.202395  1.384427  1.237124
# 3              1     0  2.096059  3.258152  7.277277  1.657483  1.468159
# 4              1     0  2.094389  3.259394  7.277268  1.665824  1.474884
# ...          ...   ...       ...       ...       ...       ...       ...
# 233663         1     0  4.398002  2.514017  8.333632  1.433443  0.262413
# 233664         1     0  4.403582  2.505987  8.340752  1.441099  0.271113
# 233665         1     0  4.389162  2.499071  8.329609  1.431733  0.273903
# 233666         1     0  3.198488  2.308803  7.106325  0.309806  0.361038
# 233667         1     0  4.752600  2.260364  8.279950  1.700334  0.524938
#
#         min_school  min_park  yearMonth
# 0         0.311712  0.082275     101-11
# 1         0.069713  0.854684     102-02
# 2         1.259014  0.942919     103-12
# 3         1.413863  1.211620     104-09
# 4         1.416363  1.219951     109-09
# ...            ...       ...        ...
# 233663    0.133083  0.240132     104-07
# 233664    0.130807  0.232397     110-03
# 233665    0.113285  0.224624     109-06
# 233666    0.450016  0.522547     102-08
# 233667    0.120486  0.493112     102-06
#
# [233668 rows x 25 columns]

# %%
data.columns
# Out:
# Index(['id', 'section', 'parking_space', 'construction_time', 'trade_time',
#        'age', 'unit_price_ping', 'area', 'trasaction_floor', 'total_floor',
#        'floor', 'type', 'room', 'lr', 'bath', 'partition', 'mgmt', 'min_inci',
#        'min_hos', 'min_mrt', 'min_mart', 'min_gas', 'min_school', 'min_park',
#        'yearMonth'],
#       dtype='object')

# %%
data.yearMonth.value_counts()
# Out:
# 102-07    4733
# 102-10    4438
# 102-11    4394
# 102-05    4165
# 102-03    4108
#           ...
# 102-00       1
# 99-11        1
# 99-08        1
# 99-03        1
# 90-72        1
# Name: yearMonth, Length: 150, dtype: int64

# %%
# 長度7也是有格式錯誤的
data[data.yearMonth == '102-00']
# Out:
#           id  section  parking_space  construction_time  trade_time  age  \
# 13600  16593        3              0            1011031     1020000    1
#
#        unit_price_ping       area trasaction_floor total_floor  ... partition  \
# 13600       322662.609  40.289944               八層          十層  ...         1
#
#        mgmt  min_inci   min_hos   min_mrt  min_mart   min_gas  min_school  \
# 13600     1  8.635804  1.455116  1.080314  0.525848  0.671512    0.726854
#
#        min_park  yearMonth
# 13600  0.139126     102-00
#
# [1 rows x 25 columns]

# %% [markdown]
# # Deal with construction_time & trade_time which length is shorter than 6

# %%
# 先把construction_time長度小於6的都篩掉(轉格式or剔除)
j = 0
for i in range(len(data)) :   
    if len(data.construction_time[i].astype(str)) < 6 :
        if len(data.construction_time[i].astype(str)) == 4 :
            data.construction_time[i] = data.construction_time[i].astype(str)+'00'
            print(data.construction_time[i])
        elif data.construction_time[i].astype(str) == '90909' :
            data.construction_time[i] = '900909'
            print(data.construction_time[i])
        else : 
            data.construction_time[i] = '1100100'
            print(data.construction_time[i])
        j += 1
        
    else :
        continue
print(j)
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_58452/2913521510.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.construction_time[i] = data.construction_time[i].astype(str)+'00'
# 650400
# 660400
# 660400
# 660400
# 570500
# 570500
# 570500
# 660400
# 660800
# 660800
# 650800
# 650800
# 660100
# 540100
# C:\Users\admin\AppData\Local\Temp/ipykernel_58452/2913521510.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.construction_time[i] = '900909'
# 900909
# C:\Users\admin\AppData\Local\Temp/ipykernel_58452/2913521510.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.construction_time[i] = '1100100'
# 1100100
# 16

# %%
# 確認construction_time有無少於長度6的日期
j = 0
for i in range(len(data)) :   
    if len(data.construction_time[i].astype(str)) < 6 :
        j += 1
        print(data.construction_time[i])
        
    else :
        continue
print(j)
# Out:
# 0

# %%
# 確認trade_time有無小於長度6的日期
j = 0
for i in range(len(data)) :   
    if len(data.trade_time[i].astype(str)) < 6 :
        j += 1
        print(data.trade_time[i])
        
    else :
        continue
print(j)
# Out:
# 90723
# 1

# %%
data[data.trade_time == 90723]
# Out:
#             id  section  parking_space  construction_time  trade_time  age  \
# 194644  293605       24              1            1021018       90723  -93
#
#         unit_price_ping      area trasaction_floor total_floor  ... partition  \
# 194644       559407.476  60.02807              十三層        二十八層  ...         1
#
#         mgmt  min_inci   min_hos   min_mrt  min_mart   min_gas  min_school  \
# 194644     1  5.259445  0.898567  0.277564   0.16025  0.195572    0.407757
#
#         min_park  yearMonth
# 194644  0.184555      90-72
#
# [1 rows x 25 columns]

# %%
# 刪除trade_time長度5單一筆資料
data = data.drop(index = {194644})

# %%
data = data.reset_index(drop = True) # 不設drop = True的話會把index也加進column

# %%
# 再次確認trade_time日期
j = 0
for i in range(len(data)) :   
    if len(data.trade_time[i].astype(str)) < 6 :
        j += 1
        print(data.trade_time[i])
        
    else :
        continue
print(j)
# Out:
# 0

# %%
data.shape
# Out:
# (233667, 25)

# %% [markdown]
# # trade_time & construction_time only has length 6、7

# %% [markdown]
# #　Deal with trade_time

# %%
# xxx_0x_0x = r'([0-9]{3}0[1-9]0[1-9])'
# xxx_0x_102x = r"([0-9]{3}0[1-9][1-2][0-9])"
# xxx_0x_3x = r"([0-9]{3}0[1-9]3[0-1])"
# xxx_1x_0x = r"([0-9]{3}1[0-2]0[1-9])"
# xxx_1x_102x = r'([0-9]{3}1[0-2][1-2][0-9])'
# xxx_1x_3x = r'([0-9]{3}1[0-2]3[0-1])'

# %%
# 先找出trade_time中不符合長度7 or 不符合條件格式的日期
data[~data.trade_time.astype(str).str.contains(r'([0-9]{3}0[1-9]0[1-9])|([0-9]{3}0[1-9][1-2][0-9])|([0-9]{3}0[1-9]3[0-1])|([0-9]{3}1[0-2]0[1-9])|([0-9]{3}1[0-2][1-2][0-9])|([0-9]{3}1[0-2]3[0-1])')]
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_58452/1783253136.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   data[~data.trade_time.astype(str).str.contains(r'([0-9]{3}0[1-9]0[1-9])|([0-9]{3}0[1-9][1-2][0-9])|([0-9]{3}0[1-9]3[0-1])|([0-9]{3}1[0-2]0[1-9])|([0-9]{3}1[0-2][1-2][0-9])|([0-9]{3}1[0-2]3[0-1])')]
#             id  section  parking_space  construction_time  trade_time  age  \
# 2232      2525        1              1            1021111      981031   -4
# 2233      2526        1              1            1021111      981115   -4
# 2237      2530        1              1            1021111      990610   -3
# 2238      2531        1              1            1021111      990510   -3
# 2239      2532        1              1            1021111      990417   -3
# ...        ...      ...            ...                ...         ...  ...
# 179458  273144       24              1            1010130      990912   -2
# 210505  324846       20              0             640906      991220   35
# 231395  360475       28              0            1010214      991220   -2
# 231396  360476       28              0            1010214      991203   -2
# 231401  360481       28              0            1010214      991208   -2
#
#         unit_price_ping       area trasaction_floor total_floor  ...  \
# 2232        313006.3672  34.951523               十層        二十三層  ...
# 2233        305161.7038  33.687210               十層        二十三層  ...
# 2237        282821.1074  66.367340              十五層        二十三層  ...
# 2238        323617.9852  33.867244              十五層        二十三層  ...
# 2239        318074.1586  32.099577              十五層        二十三層  ...
# ...                 ...        ...              ...         ...  ...
# 179458      556402.5038  88.335730               三層         二十層  ...
# 210505      101405.4150  19.722900                全          三層  ...
# 231395      159501.5442  93.541840                全          五層  ...
# 231396      151438.6980  91.786730                全          五層  ...
# 231401      150149.4360  83.783580                全          五層  ...
#
#        partition  mgmt  min_inci   min_hos   min_mrt  min_mart   min_gas  \
# 2232           1     1  8.245495  1.521758  1.225684  1.349076  0.114277
# 2233           1     1  8.249135  1.518393  1.222813  1.346343  0.114473
# 2237           1     1  8.250778  1.514524  1.216698  1.339760  0.124824
# 2238           1     1  8.245495  1.521758  1.225684  1.349076  0.114277
# 2239           1     1  8.249135  1.518393  1.222813  1.346343  0.114473
# ...          ...   ...       ...       ...       ...       ...       ...
# 179458         1     1  4.789390  1.055848  0.246552  0.610172  0.114069
# 210505         1     0  2.976327  0.295437  1.173682  0.307562  0.672182
# 231395         1     1  2.478946  2.192669  6.388612  0.637798  0.376001
# 231396         1     1  2.481278  2.188354  6.389198  0.634639  0.375079
# 231401         1     1  2.467351  2.198179  6.379222  0.649810  0.386030
#
#         min_school  min_park  yearMonth
# 2232      0.707744  1.333000      98-10
# 2233      0.707838  1.333674      98-11
# 2237      0.697410  1.343794      99-06
# 2238      0.707744  1.333000      99-05
# 2239      0.707838  1.333674      99-04
# ...            ...       ...        ...
# 179458    0.282471  0.086236      99-09
# 210505    0.321232  0.061165      99-12
# 231395    0.442563  0.186857      99-12
# 231396    0.438077  0.186027      99-12
# 231401    0.452601  0.180615      99-12
#
# [122 rows x 25 columns]

# %%
not_match = data[~data.trade_time.astype(str).str.contains(r'([0-9]{3}0[1-9]0[1-9])|([0-9]{3}0[1-9][1-2][0-9])|([0-9]{3}0[1-9]3[0-1])|([0-9]{3}1[0-2]0[1-9])|([0-9]{3}1[0-2][1-2][0-9])|([0-9]{3}1[0-2]3[0-1])')]
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_58452/3591601976.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   not_match = data[~data.trade_time.astype(str).str.contains(r'([0-9]{3}0[1-9]0[1-9])|([0-9]{3}0[1-9][1-2][0-9])|([0-9]{3}0[1-9]3[0-1])|([0-9]{3}1[0-2]0[1-9])|([0-9]{3}1[0-2][1-2][0-9])|([0-9]{3}1[0-2]3[0-1])')]

# %%
# 重新編碼才能用[]取值
not_match = not_match.reset_index(drop = True)

# %%
# trade_time中長度7但不符合條件的日期
for i in range(len(not_match)) :
    if len(not_match.trade_time[i].astype(str)) == 7:
        print(not_match.trade_time[i])
    else :
        continue
# Out:
# 1020000
# 1040000
# 1040000

# %%
# 將trade_time中長度7但不符條件的日期刪除
# data.trade_time.isin([1020000, 1040000]) -> Series.isin(list)
data = data[data.trade_time != 1020000]

# %%
data = data[data.trade_time != 1040000]

# %%
data
# Out:
#             id  section  parking_space  construction_time  trade_time  age  \
# 0            2        1              0             820504     1011122   19
# 1            3        1              1             850923     1020204   17
# 2            6        1              0             700820     1031209   33
# 3            7        1              0             690325     1040913   35
# 4            8        1              0             690325     1090923   40
# ...        ...      ...            ...                ...         ...  ...
# 233662  367014       28              1             870210     1040729   17
# 233663  367015       28              1             870210     1100329   23
# 233664  367016       28              1             870210     1090608   22
# 233665  367017       28              0             780615     1020804   24
# 233666  367018       28              0             860625     1020618   16
#
#         unit_price_ping       area trasaction_floor total_floor  ...  \
# 0           115937.7118  30.878789               二層         十三層  ...
# 1           234202.7068  59.350563             二十四層         三十層  ...
# 2           103878.1534  24.066766               二層          二層  ...
# 3           110000.4950  73.568000                全          二層  ...
# 4            99940.9456  80.047632                全          二層  ...
# ...                 ...        ...              ...         ...  ...
# 233662       74909.4280  76.092230                全          四層  ...
# 233663      209769.5390  69.123790         二層，三層，四層          四層  ...
# 233664      210586.0716  68.285930         二層，三層，四層          四層  ...
# 233665      114698.0368  36.618050               五層          五層  ...
# 233666      106949.2416  18.700540               五層          七層  ...
#
#        partition  mgmt  min_inci   min_hos   min_mrt  min_mart   min_gas  \
# 0              1     1  3.216651  2.360415  6.347960  0.421408  0.259130
# 1              1     1  8.482000  1.320465  0.893130  0.957701  0.794212
# 2              1     0  2.242399  3.157690  7.202395  1.384427  1.237124
# 3              1     0  2.096059  3.258152  7.277277  1.657483  1.468159
# 4              1     0  2.094389  3.259394  7.277268  1.665824  1.474884
# ...          ...   ...       ...       ...       ...       ...       ...
# 233662         1     0  4.398002  2.514017  8.333632  1.433443  0.262413
# 233663         1     0  4.403582  2.505987  8.340752  1.441099  0.271113
# 233664         1     0  4.389162  2.499071  8.329609  1.431733  0.273903
# 233665         1     0  3.198488  2.308803  7.106325  0.309806  0.361038
# 233666         1     0  4.752600  2.260364  8.279950  1.700334  0.524938
#
#         min_school  min_park  yearMonth
# 0         0.311712  0.082275     101-11
# 1         0.069713  0.854684     102-02
# 2         1.259014  0.942919     103-12
# 3         1.413863  1.211620     104-09
# 4         1.416363  1.219951     109-09
# ...            ...       ...        ...
# 233662    0.133083  0.240132     104-07
# 233663    0.130807  0.232397     110-03
# 233664    0.113285  0.224624     109-06
# 233665    0.450016  0.522547     102-08
# 233666    0.120486  0.493112     102-06
#
# [233664 rows x 25 columns]

# %%
# 再套一次，這次內容就會是不符長度7的日期
not_match = data[~data.trade_time.astype(str).str.contains(r'([0-9]{3}0[1-9]0[1-9])|([0-9]{3}0[1-9][1-2][0-9])|([0-9]{3}0[1-9]3[0-1])|([0-9]{3}1[0-2]0[1-9])|([0-9]{3}1[0-2][1-2][0-9])|([0-9]{3}1[0-2]3[0-1])')]
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_58452/2927718375.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   not_match = data[~data.trade_time.astype(str).str.contains(r'([0-9]{3}0[1-9]0[1-9])|([0-9]{3}0[1-9][1-2][0-9])|([0-9]{3}0[1-9]3[0-1])|([0-9]{3}1[0-2]0[1-9])|([0-9]{3}1[0-2][1-2][0-9])|([0-9]{3}1[0-2]3[0-1])')]

# %%
# 找出剩餘日期(長度6)不符合格式的日期
not_match[not_match.trade_time.astype(str).str.contains(r'([0-9]{2}0[1-9]0[1-9])|([0-9]{2}0[1-9][1-2][0-9])|([0-9]{2}0[1-9]3[0-1])|([0-9]{2}1[0-2]0[1-9])|([0-9]{2}1[0-2][1-2][0-9])|([0-9]{2}1[0-2]3[0-1])')]
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_58452/2643630143.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   not_match[not_match.trade_time.astype(str).str.contains(r'([0-9]{2}0[1-9]0[1-9])|([0-9]{2}0[1-9][1-2][0-9])|([0-9]{2}0[1-9]3[0-1])|([0-9]{2}1[0-2]0[1-9])|([0-9]{2}1[0-2][1-2][0-9])|([0-9]{2}1[0-2]3[0-1])')]
#             id  section  parking_space  construction_time  trade_time  age  \
# 2232      2525        1              1            1021111      981031   -4
# 2233      2526        1              1            1021111      981115   -4
# 2237      2530        1              1            1021111      990610   -3
# 2238      2531        1              1            1021111      990510   -3
# 2239      2532        1              1            1021111      990417   -3
# ...        ...      ...            ...                ...         ...  ...
# 179458  273144       24              1            1010130      990912   -2
# 210505  324846       20              0             640906      991220   35
# 231395  360475       28              0            1010214      991220   -2
# 231396  360476       28              0            1010214      991203   -2
# 231401  360481       28              0            1010214      991208   -2
#
#         unit_price_ping       area trasaction_floor total_floor  ...  \
# 2232        313006.3672  34.951523               十層        二十三層  ...
# 2233        305161.7038  33.687210               十層        二十三層  ...
# 2237        282821.1074  66.367340              十五層        二十三層  ...
# 2238        323617.9852  33.867244              十五層        二十三層  ...
# 2239        318074.1586  32.099577              十五層        二十三層  ...
# ...                 ...        ...              ...         ...  ...
# 179458      556402.5038  88.335730               三層         二十層  ...
# 210505      101405.4150  19.722900                全          三層  ...
# 231395      159501.5442  93.541840                全          五層  ...
# 231396      151438.6980  91.786730                全          五層  ...
# 231401      150149.4360  83.783580                全          五層  ...
#
#        partition  mgmt  min_inci   min_hos   min_mrt  min_mart   min_gas  \
# 2232           1     1  8.245495  1.521758  1.225684  1.349076  0.114277
# 2233           1     1  8.249135  1.518393  1.222813  1.346343  0.114473
# 2237           1     1  8.250778  1.514524  1.216698  1.339760  0.124824
# 2238           1     1  8.245495  1.521758  1.225684  1.349076  0.114277
# 2239           1     1  8.249135  1.518393  1.222813  1.346343  0.114473
# ...          ...   ...       ...       ...       ...       ...       ...
# 179458         1     1  4.789390  1.055848  0.246552  0.610172  0.114069
# 210505         1     0  2.976327  0.295437  1.173682  0.307562  0.672182
# 231395         1     1  2.478946  2.192669  6.388612  0.637798  0.376001
# 231396         1     1  2.481278  2.188354  6.389198  0.634639  0.375079
# 231401         1     1  2.467351  2.198179  6.379222  0.649810  0.386030
#
#         min_school  min_park  yearMonth
# 2232      0.707744  1.333000      98-10
# 2233      0.707838  1.333674      98-11
# 2237      0.697410  1.343794      99-06
# 2238      0.707744  1.333000      99-05
# 2239      0.707838  1.333674      99-04
# ...            ...       ...        ...
# 179458    0.282471  0.086236      99-09
# 210505    0.321232  0.061165      99-12
# 231395    0.442563  0.186857      99-12
# 231396    0.438077  0.186027      99-12
# 231401    0.452601  0.180615      99-12
#
# [119 rows x 25 columns]

# %% [markdown]
# # Deal with construction_time

# %%
# 先找出construntion_time中不符合長度7 or 不符合條件格式的日期
data[~data.construction_time.astype(str).str.contains(r'([0-9]{3}0[1-9]0[1-9])|([0-9]{3}0[1-9][1-2][0-9])|([0-9]{3}0[1-9]3[0-1])|([0-9]{3}1[0-2]0[1-9])|([0-9]{3}1[0-2][1-2][0-9])|([0-9]{3}1[0-2]3[0-1])')]
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_58452/4006146210.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   data[~data.construction_time.astype(str).str.contains(r'([0-9]{3}0[1-9]0[1-9])|([0-9]{3}0[1-9][1-2][0-9])|([0-9]{3}0[1-9]3[0-1])|([0-9]{3}1[0-2]0[1-9])|([0-9]{3}1[0-2][1-2][0-9])|([0-9]{3}1[0-2]3[0-1])')]
#             id  section  parking_space  construction_time  trade_time  age  \
# 0            2        1              0             820504     1011122   19
# 1            3        1              1             850923     1020204   17
# 2            6        1              0             700820     1031209   33
# 3            7        1              0             690325     1040913   35
# 4            8        1              0             690325     1090923   40
# ...        ...      ...            ...                ...         ...  ...
# 233662  367014       28              1             870210     1040729   17
# 233663  367015       28              1             870210     1100329   23
# 233664  367016       28              1             870210     1090608   22
# 233665  367017       28              0             780615     1020804   24
# 233666  367018       28              0             860625     1020618   16
#
#         unit_price_ping       area trasaction_floor total_floor  ...  \
# 0           115937.7118  30.878789               二層         十三層  ...
# 1           234202.7068  59.350563             二十四層         三十層  ...
# 2           103878.1534  24.066766               二層          二層  ...
# 3           110000.4950  73.568000                全          二層  ...
# 4            99940.9456  80.047632                全          二層  ...
# ...                 ...        ...              ...         ...  ...
# 233662       74909.4280  76.092230                全          四層  ...
# 233663      209769.5390  69.123790         二層，三層，四層          四層  ...
# 233664      210586.0716  68.285930         二層，三層，四層          四層  ...
# 233665      114698.0368  36.618050               五層          五層  ...
# 233666      106949.2416  18.700540               五層          七層  ...
#
#        partition  mgmt  min_inci   min_hos   min_mrt  min_mart   min_gas  \
# 0              1     1  3.216651  2.360415  6.347960  0.421408  0.259130
# 1              1     1  8.482000  1.320465  0.893130  0.957701  0.794212
# 2              1     0  2.242399  3.157690  7.202395  1.384427  1.237124
# 3              1     0  2.096059  3.258152  7.277277  1.657483  1.468159
# 4              1     0  2.094389  3.259394  7.277268  1.665824  1.474884
# ...          ...   ...       ...       ...       ...       ...       ...
# 233662         1     0  4.398002  2.514017  8.333632  1.433443  0.262413
# 233663         1     0  4.403582  2.505987  8.340752  1.441099  0.271113
# 233664         1     0  4.389162  2.499071  8.329609  1.431733  0.273903
# 233665         1     0  3.198488  2.308803  7.106325  0.309806  0.361038
# 233666         1     0  4.752600  2.260364  8.279950  1.700334  0.524938
#
#         min_school  min_park  yearMonth
# 0         0.311712  0.082275     101-11
# 1         0.069713  0.854684     102-02
# 2         1.259014  0.942919     103-12
# 3         1.413863  1.211620     104-09
# 4         1.416363  1.219951     109-09
# ...            ...       ...        ...
# 233662    0.133083  0.240132     104-07
# 233663    0.130807  0.232397     110-03
# 233664    0.113285  0.224624     109-06
# 233665    0.450016  0.522547     102-08
# 233666    0.120486  0.493112     102-06
#
# [187522 rows x 25 columns]

# %%
not_match1 = data[~data.construction_time.astype(str).str.contains(r'([0-9]{3}0[1-9]0[1-9])|([0-9]{3}0[1-9][1-2][0-9])|([0-9]{3}0[1-9]3[0-1])|([0-9]{3}1[0-2]0[1-9])|([0-9]{3}1[0-2][1-2][0-9])|([0-9]{3}1[0-2]3[0-1])')]
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_58452/756515756.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   not_match1 = data[~data.construction_time.astype(str).str.contains(r'([0-9]{3}0[1-9]0[1-9])|([0-9]{3}0[1-9][1-2][0-9])|([0-9]{3}0[1-9]3[0-1])|([0-9]{3}1[0-2]0[1-9])|([0-9]{3}1[0-2][1-2][0-9])|([0-9]{3}1[0-2]3[0-1])')]

# %%
# 重新編碼才能用[]取值
not_match1 = not_match1.reset_index(drop = True)

# %%
# construction_time中長度7但不符合條件的日期
for i in range(len(not_match1)) :
    if len(not_match1.construction_time[i].astype(str)) == 7:
        print(not_match1.construction_time[i])
    else :
        continue
# Out:
# 1100100

# %%
# 將construction_time中長度7但不符條件的日期保留

# %%
data
# Out:
#             id  section  parking_space  construction_time  trade_time  age  \
# 0            2        1              0             820504     1011122   19
# 1            3        1              1             850923     1020204   17
# 2            6        1              0             700820     1031209   33
# 3            7        1              0             690325     1040913   35
# 4            8        1              0             690325     1090923   40
# ...        ...      ...            ...                ...         ...  ...
# 233662  367014       28              1             870210     1040729   17
# 233663  367015       28              1             870210     1100329   23
# 233664  367016       28              1             870210     1090608   22
# 233665  367017       28              0             780615     1020804   24
# 233666  367018       28              0             860625     1020618   16
#
#         unit_price_ping       area trasaction_floor total_floor  ...  \
# 0           115937.7118  30.878789               二層         十三層  ...
# 1           234202.7068  59.350563             二十四層         三十層  ...
# 2           103878.1534  24.066766               二層          二層  ...
# 3           110000.4950  73.568000                全          二層  ...
# 4            99940.9456  80.047632                全          二層  ...
# ...                 ...        ...              ...         ...  ...
# 233662       74909.4280  76.092230                全          四層  ...
# 233663      209769.5390  69.123790         二層，三層，四層          四層  ...
# 233664      210586.0716  68.285930         二層，三層，四層          四層  ...
# 233665      114698.0368  36.618050               五層          五層  ...
# 233666      106949.2416  18.700540               五層          七層  ...
#
#        partition  mgmt  min_inci   min_hos   min_mrt  min_mart   min_gas  \
# 0              1     1  3.216651  2.360415  6.347960  0.421408  0.259130
# 1              1     1  8.482000  1.320465  0.893130  0.957701  0.794212
# 2              1     0  2.242399  3.157690  7.202395  1.384427  1.237124
# 3              1     0  2.096059  3.258152  7.277277  1.657483  1.468159
# 4              1     0  2.094389  3.259394  7.277268  1.665824  1.474884
# ...          ...   ...       ...       ...       ...       ...       ...
# 233662         1     0  4.398002  2.514017  8.333632  1.433443  0.262413
# 233663         1     0  4.403582  2.505987  8.340752  1.441099  0.271113
# 233664         1     0  4.389162  2.499071  8.329609  1.431733  0.273903
# 233665         1     0  3.198488  2.308803  7.106325  0.309806  0.361038
# 233666         1     0  4.752600  2.260364  8.279950  1.700334  0.524938
#
#         min_school  min_park  yearMonth
# 0         0.311712  0.082275     101-11
# 1         0.069713  0.854684     102-02
# 2         1.259014  0.942919     103-12
# 3         1.413863  1.211620     104-09
# 4         1.416363  1.219951     109-09
# ...            ...       ...        ...
# 233662    0.133083  0.240132     104-07
# 233663    0.130807  0.232397     110-03
# 233664    0.113285  0.224624     109-06
# 233665    0.450016  0.522547     102-08
# 233666    0.120486  0.493112     102-06
#
# [233664 rows x 25 columns]

# %%
# 找出日期(長度6&7)中不符合格式的日期，上面沒有將長度7的篩掉所以這裡仍有
not_match1[~not_match1.construction_time.astype(str).str.contains(r'([0-9]{2}0[1-9]0[1-9])|([0-9]{2}0[1-9][1-2][0-9])|([0-9]{2}0[1-9]3[0-1])|([0-9]{2}1[0-2]0[1-9])|([0-9]{2}1[0-2][1-2][0-9])|([0-9]{2}1[0-2]3[0-1])')]
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_58452/2029968317.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   not_match1[~not_match1.construction_time.astype(str).str.contains(r'([0-9]{2}0[1-9]0[1-9])|([0-9]{2}0[1-9][1-2][0-9])|([0-9]{2}0[1-9]3[0-1])|([0-9]{2}1[0-2]0[1-9])|([0-9]{2}1[0-2][1-2][0-9])|([0-9]{2}1[0-2]3[0-1])')]
#             id  section  parking_space  construction_time  trade_time  age  \
# 2090      3744        1              0             700100     1090527   39
# 7350     10538        3              0             611000     1090629   48
# 8873     13062        3              0             650400     1061117  106
# 9139     13797        3              0             660400     1040814  104
# 9140     13798        3              0             660400     1051025  105
# 9141     13799        3              0             660400     1040119  104
# 10374    16229        3              0             570500     1040512  104
# 10375    16230        3              0             570500     1040512  104
# 10376    16232        3              0             570500     1020121  102
# 14521    22384        3              0             610300     1090817   48
# 14522    22385        3              0             610300     1090817   48
# 14802    22806        3              0             660400     1090914  109
# 16601    26492        3              0             660800     1070508  107
# 16602    26493        3              0             660800     1031221  103
# 17929    28792        3              0             650800     1090801  109
# 17930    28793        3              0             650800     1091102  109
# 18720    30952        3              0             660100     1071231  107
# 46850    81929        8              0             580600     1090529   51
# 55770    95581        8              0             531200     1091015   56
# 55771    95582        8              0             531200     1091015   56
# 55772    95583        8              0             531200     1091015   56
# 64197   115256        9              0             410000     1090723   68
# 86915   149528        7              0             540100     1070922  107
# 151007  294343       20              0            1100100     1060103  105
# 164457  320385       20              0             571200     1090521   52
# 164759  320765       20              0             570100     1100329   53
# 185321  360554       28              0             700200     1091014   39
#
#         unit_price_ping       area trasaction_floor total_floor  ...  \
# 2090       3.286097e+05  69.992153                全          二層  ...
# 7350       3.565074e+05  15.427520               二層          四層  ...
# 8873       2.700508e+05  21.477537            三層，陽台          四層  ...
# 9139       2.668541e+05  25.107466            三層，陽台          四層  ...
# 9140       3.026989e+05  25.107573            三層，陽台          四層  ...
# 9141       3.663355e+05  14.822544               四層          四層  ...
# 10374      3.718298e+05  40.341222                全          三層  ...
# 10375      3.443784e+05  43.556934                全          三層  ...
# 10376      5.050866e+05  87.114171                全          三層  ...
# 14521      6.000258e+05  44.164963            一層，騎樓          四層  ...
# 14522      2.490656e+05  44.165273               三層          四層  ...
# 14802      1.859512e+05  24.200000            四層，陽台          四層  ...
# 16601      6.164854e+05  22.385058               一層          四層  ...
# 16602      3.343784e+05  26.317611            四層，陽台          四層  ...
# 17929      3.180576e+05  19.965025            二層，陽台          四層  ...
# 17930      3.456049e+05  19.965087            二層，陽台          四層  ...
# 18720      3.014096e+05  30.855159            四層，陽台          四層  ...
# 46850      1.788868e+05  25.043890               三層          四層  ...
# 55770      1.307821e+06  22.990000                全          二層  ...
# 55771      1.323008e+06  24.200020                全          二層  ...
# 55772      1.322611e+06  22.989980                全          二層  ...
# 64197      7.809986e+05  69.142560      一層，二層，三層，騎樓          四層  ...
# 86915      7.313719e+05  43.069940                全          二層  ...
# 151007     6.591831e+05  15.170360                全          一層  ...
# 164457     3.176477e+05  22.037090            二層，陽台          三層  ...
# 164759     6.354210e+05  24.865510                全          二層  ...
# 185321     6.921023e+04  57.795190                全          二層  ...
#
#        partition  mgmt  min_inci   min_hos   min_mrt  min_mart   min_gas  \
# 2090           1     1  8.011624  1.957085  1.706434  1.858026  0.504761
# 7350           1     0  6.740014  0.473665  0.548578  0.308227  0.281768
# 8873           1     0  5.991975  0.654184  0.448978  0.288690  0.540254
# 9139           1     0  6.423079  0.471686  0.351446  0.324888  0.236027
# 9140           1     0  6.423079  0.471686  0.351446  0.324888  0.236027
# 9141           1     0  6.423079  0.471686  0.351446  0.324888  0.236027
# 10374          1     0  8.280465  1.500156  0.425542  0.113229  0.085041
# 10375          1     0  8.278081  1.496444  0.421925  0.109140  0.086515
# 10376          1     0  8.270434  1.487598  0.411700  0.098308  0.089534
# 14521          1     0  7.455753  1.006602  0.613375  0.420553  0.382593
# 14522          1     0  7.455753  1.006602  0.613375  0.420553  0.382593
# 14802          1     0  5.415022  1.041555  0.871959  0.416198  0.826309
# 16601          1     0  5.609148  0.680296  0.419607  0.161170  0.448569
# 16602          1     0  5.615199  0.674195  0.431060  0.155823  0.441688
# 17929          1     0  5.520086  0.842748  0.694571  0.190028  0.615762
# 17930          1     0  5.520086  0.842748  0.694571  0.190028  0.615762
# 18720          1     0  5.615880  0.835382  0.659623  0.339486  0.629817
# 46850          1     0  3.389272  0.676346  0.344850  0.546714  1.140475
# 55770          1     0  4.784063  0.129455  0.085294  0.133539  0.092720
# 55771          1     0  4.790602  0.119125  0.096651  0.144738  0.084061
# 55772          1     0  4.788210  0.122264  0.092836  0.140968  0.086546
# 64197          1     0  5.260818  0.508689  0.384149  0.319658  1.286247
# 86915          1     0  1.820963  1.376397  0.889096  0.079362  0.152035
# 151007         1     0  3.002168  0.358144  0.875458  0.535644  0.842623
# 164457         1     0  3.676566  0.198632  1.353638  0.311343  0.434226
# 164759         1     0  4.199841  0.312593  1.308067  0.412511  0.789022
# 185321         1     0  1.930117  2.044785  5.697831  1.231612  1.070609
#
#         min_school  min_park  yearMonth
# 2090      1.316579  0.716138     109-05
# 7350      0.449183  0.205146     109-06
# 8873      0.305994  0.230446     106-11
# 9139      0.414223  0.337576     104-08
# 9140      0.414223  0.337576     105-10
# 9141      0.414223  0.337576     104-01
# 10374     0.556027  0.190839     104-05
# 10375     0.552364  0.192886     104-05
# 10376     0.542052  0.200007     102-01
# 14521     0.652252  0.107774     109-08
# 14522     0.652252  0.107774     109-08
# 14802     0.344843  0.441860     109-09
# 16601     0.135079  0.081559     107-05
# 16602     0.129457  0.071109     103-12
# 17929     0.213753  0.237889     109-08
# 17930     0.213753  0.237889     109-11
# 18720     0.132903  0.400221     107-12
# 46850     0.124103  0.316970     109-05
# 55770     0.145775  0.233569     109-10
# 55771     0.151794  0.227924     109-10
# 55772     0.149485  0.229983     109-10
# 64197     0.798578  0.083950     109-07
# 86915     0.315954  0.146067     107-09
# 151007    0.253405  0.202983     106-01
# 164457    0.373812  0.314179     109-05
# 164759    0.095216  0.258575     110-03
# 185321    0.879246  0.518490     109-10
#
# [27 rows x 25 columns]

# %%
# 我們只要篩到月份就好，所以日期是00的可留，但月份00的要刪
not_match1[~not_match1.construction_time.astype(str).str.contains(r'([0-9]{2}0[1-9])|([0-9]{2}0[1-9])|([0-9]{2}0[1-9])|([0-9]{2}1[0-2])|([0-9]{2}1[0-2])|([0-9]{2}1[0-2])')]
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_58452/4224784676.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   not_match1[~not_match1.construction_time.astype(str).str.contains(r'([0-9]{2}0[1-9])|([0-9]{2}0[1-9])|([0-9]{2}0[1-9])|([0-9]{2}1[0-2])|([0-9]{2}1[0-2])|([0-9]{2}1[0-2])')]
#            id  section  parking_space  construction_time  trade_time  age  \
# 64197  115256        9              0             410000     1090723   68
#
#        unit_price_ping      area trasaction_floor total_floor  ... partition  \
# 64197      780998.5558  69.14256      一層，二層，三層，騎樓          四層  ...         1
#
#        mgmt  min_inci   min_hos   min_mrt  min_mart   min_gas  min_school  \
# 64197     0  5.260818  0.508689  0.384149  0.319658  1.286247    0.798578
#
#        min_park  yearMonth
# 64197   0.08395     109-07
#
# [1 rows x 25 columns]

# %%
# 刪除月份00的資料
data = data.drop(index = {71237})

# %%
data
# Out:
#             id  section  parking_space  construction_time  trade_time  age  \
# 0            2        1              0             820504     1011122   19
# 1            3        1              1             850923     1020204   17
# 2            6        1              0             700820     1031209   33
# 3            7        1              0             690325     1040913   35
# 4            8        1              0             690325     1090923   40
# ...        ...      ...            ...                ...         ...  ...
# 233662  367014       28              1             870210     1040729   17
# 233663  367015       28              1             870210     1100329   23
# 233664  367016       28              1             870210     1090608   22
# 233665  367017       28              0             780615     1020804   24
# 233666  367018       28              0             860625     1020618   16
#
#         unit_price_ping       area trasaction_floor total_floor  ...  \
# 0           115937.7118  30.878789               二層         十三層  ...
# 1           234202.7068  59.350563             二十四層         三十層  ...
# 2           103878.1534  24.066766               二層          二層  ...
# 3           110000.4950  73.568000                全          二層  ...
# 4            99940.9456  80.047632                全          二層  ...
# ...                 ...        ...              ...         ...  ...
# 233662       74909.4280  76.092230                全          四層  ...
# 233663      209769.5390  69.123790         二層，三層，四層          四層  ...
# 233664      210586.0716  68.285930         二層，三層，四層          四層  ...
# 233665      114698.0368  36.618050               五層          五層  ...
# 233666      106949.2416  18.700540               五層          七層  ...
#
#        partition  mgmt  min_inci   min_hos   min_mrt  min_mart   min_gas  \
# 0              1     1  3.216651  2.360415  6.347960  0.421408  0.259130
# 1              1     1  8.482000  1.320465  0.893130  0.957701  0.794212
# 2              1     0  2.242399  3.157690  7.202395  1.384427  1.237124
# 3              1     0  2.096059  3.258152  7.277277  1.657483  1.468159
# 4              1     0  2.094389  3.259394  7.277268  1.665824  1.474884
# ...          ...   ...       ...       ...       ...       ...       ...
# 233662         1     0  4.398002  2.514017  8.333632  1.433443  0.262413
# 233663         1     0  4.403582  2.505987  8.340752  1.441099  0.271113
# 233664         1     0  4.389162  2.499071  8.329609  1.431733  0.273903
# 233665         1     0  3.198488  2.308803  7.106325  0.309806  0.361038
# 233666         1     0  4.752600  2.260364  8.279950  1.700334  0.524938
#
#         min_school  min_park  yearMonth
# 0         0.311712  0.082275     101-11
# 1         0.069713  0.854684     102-02
# 2         1.259014  0.942919     103-12
# 3         1.413863  1.211620     104-09
# 4         1.416363  1.219951     109-09
# ...            ...       ...        ...
# 233662    0.133083  0.240132     104-07
# 233663    0.130807  0.232397     110-03
# 233664    0.113285  0.224624     109-06
# 233665    0.450016  0.522547     102-08
# 233666    0.120486  0.493112     102-06
#
# [233663 rows x 25 columns]

# %% [markdown]
# # Add column yearMonth for format xxx-xx/xx-xx

# %%
data.trade_time = data.trade_time.astype(str)

# %%
data = data.reset_index(drop = True)

# %%
from time import time
time1 = time()
for i in range(len(data)) :
    if len(data.trade_time[i]) == 7:
        data.yearMonth[i] = data.trade_time[i][0:3]+'-'+data.trade_time[i][3:5]
    else :
        data.yearMonth[i] = data.trade_time[i][0:2]+'-'+data.trade_time[i][2:4]
        
print(f"總共花費{time()-time1}")
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_58452/1717697203.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.yearMonth[i] = data.trade_time[i][0:3]+'-'+data.trade_time[i][3:5]
# C:\Users\admin\AppData\Local\Temp/ipykernel_58452/1717697203.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.yearMonth[i] = data.trade_time[i][0:2]+'-'+data.trade_time[i][2:4]
# 總共花費473.5825080871582

# %%
data.yearMonth.unique()
# Out:
# array(['101-11', '102-02', '103-12', '104-09', '109-09', '109-11',
#        '102-03', '102-05', '101-12', '106-05', '102-12', '104-10',
#        '101-10', '101-07', '101-09', '109-07', '102-06', '109-06',
#        '109-10', '103-08', '102-09', '103-11', '105-10', '102-08',
#        '109-08', '106-02', '108-07', '106-08', '104-04', '108-12',
#        '106-09', '104-05', '102-11', '103-10', '108-11', '105-11',
#        '106-04', '103-04', '106-07', '103-06', '108-06', '108-08',
#        '107-10', '107-11', '104-11', '102-10', '102-07', '105-06',
#        '108-10', '105-03', '108-04', '102-04', '108-09', '107-07',
#        '108-05', '110-05', '107-05', '103-03', '107-09', '103-01',
#        '109-04', '105-01', '107-01', '110-04', '109-05', '104-02',
#        '104-08', '104-03', '108-02', '105-12', '103-05', '109-02',
#        '105-08', '104-12', '103-07', '102-01', '109-03', '107-04',
#        '108-01', '110-03', '110-02', '101-08', '107-02', '107-08',
#        '106-10', '109-01', '106-03', '108-03', '106-06', '104-06',
#        '106-12', '110-01', '104-07', '105-07', '105-05', '106-11',
#        '107-12', '105-09', '103-02', '107-03', '106-01', '105-02',
#        '107-06', '104-01', '103-09', '105-04', '109-12', '101-04',
#        '101-06', '98-10', '98-11', '101-05', '99-06', '99-05', '99-04',
#        '98-12', '99-01', '99-03', '100-07', '99-07', '99-02', '100-10',
#        '100-09', '100-11', '100-06', '101-01', '100-08', '100-12',
#        '100-01', '100-04', '101-03', '101-02', '99-08', '99-11', '99-09',
#        '99-12', '100-02', '99-10', '96-01', '98-06', '98-03', '100-05',
#        '97-05', '97-06', '97-12', '100-03', '95-02'], dtype=object)

# %% [markdown]
# # Add column age for house age

# %%
data.trade_time = data.trade_time.astype(int)

# %%
import math

# %%
time2 = time()
for i in range(len(data)) :
    data.age[i] = math.floor((data.trade_time[i]-data.construction_time[i])/10000)
print(f"總共花費{time()-time2}")
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_58452/449417316.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.age[i] = math.floor((data.trade_time[i]-data.construction_time[i])/10000)
# 總共花費164.88727712631226

# %%
data.age.unique()
# Out:
# array([19, 16, 33, 35, 40, 18, 17, 30, 20,  1,  2, 38, 31, 22, 26, 25, 23,
#        21, 24, 15, 39, 34, 36, 27, 28, 32, 29,  0, 14, 11,  8,  7, 13,  5,
#         6, 10,  9, 37, 49,  3,  4, 41, 12, -1, -2, 48, 42, -5, -4, -3, 45,
#        44, 47, 56, 54, 43, 46, 50, 52, 51, 53, 59, 55, 57, 58, 63, 67, 62,
#        60, 65, 69, 71, -6, 91, 89, 64, 70, 61, 68], dtype=int64)

# %%
data[data['age'].isin([0,1,2,-1,-2,-3,-4,-5,-6])]
# Out:
#             id  section  parking_space  construction_time  trade_time  age  \
# 13          17        1              1            1000414     1011012    1
# 14          18        1              1            1000414     1010703    1
# 15          19        1              1            1000414     1020328    1
# 16          20        1              1            1000414     1010721    1
# 17          22        1              1            1000414     1010721    1
# ...        ...      ...            ...                ...         ...  ...
# 231638  361115       28              1            1041030     1050617    0
# 232241  362867       28              0            1001230     1020315    1
# 232242  362869       28              1            1001230     1011126    0
# 232401  363048       28              0            1060707     1080420    1
# 232643  363331       28              0            1081225     1100418    1
#
#         unit_price_ping       area trasaction_floor total_floor  ...  \
# 13          177815.6762  64.280336              十四層         十九層  ...
# 14          179967.7520  56.510378              十五層         十九層  ...
# 15          200837.2674  64.281188              十七層         十九層  ...
# 16          137676.6526  56.509472               五層         十九層  ...
# 17          175924.7586  61.447000              十三層         十九層  ...
# ...                 ...        ...              ...         ...  ...
# 231638       50165.5150  35.482700               四層          五層  ...
# 232241      256576.3612  72.103620                全          四層  ...
# 232242      250939.9722  72.527630                全          四層  ...
# 232401      217812.5504  34.433430               二層          四層  ...
# 232643      229164.6676  50.967950                全          三層  ...
#
#        partition  mgmt  min_inci   min_hos   min_mrt  min_mart   min_gas  \
# 13             1     1  3.449971  2.309428  6.167956  0.109811  0.290849
# 14             1     1  3.449971  2.309428  6.167956  0.109811  0.290849
# 15             1     1  3.449971  2.309428  6.167956  0.109811  0.290849
# 16             1     1  3.449971  2.309428  6.167956  0.109811  0.290849
# 17             1     1  3.441805  2.313145  6.174962  0.118508  0.287999
# ...          ...   ...       ...       ...       ...       ...       ...
# 231638         1     0  3.510331  1.414780  7.013821  0.739383  0.109684
# 232241         1     1  3.746962  2.622380  7.679056  0.804068  0.227952
# 232242         1     0  3.752737  2.609018  7.679691  0.799821  0.241499
# 232401         1     1  2.990713  2.167275  6.869139  0.199889  0.184764
# 232643         1     0  4.587341  1.375694  8.803339  3.281222  0.901163
#
#         min_school  min_park  yearMonth
# 13        0.032921  0.007565     101-10
# 14        0.032921  0.007565     101-07
# 15        0.032921  0.007565     102-03
# 16        0.032921  0.007565     101-07
# 17        0.030001  0.001564     101-07
# ...            ...       ...        ...
# 231638    0.805026  0.530270     105-06
# 232241    0.151608  0.688710     102-03
# 232242    0.144059  0.676206     101-11
# 232401    0.418540  0.562239     108-04
# 232643    1.471958  1.168530     110-04
#
# [38901 rows x 25 columns]

# %%
data.to_csv('deal_with_date.csv', index = False, encoding = 'utf-8')

# %% [markdown]
# # Deal with floor

# %%
house = pd.read_csv('data/table/table_for_model.csv')
house.head()
# Out:
#    id  section  parking_space  construction_time  trade_time  age  \
# 0   2        1              0             820504     1011122   19
# 1   3        1              1             850923     1020204   16
# 2   6        1              0             700820     1031209   33
# 3   7        1              0             690325     1040913   35
# 4   8        1              0             690325     1090923   40
#
#    unit_price_ping       area trasaction_floor total_floor floor  type  room  \
# 0      115937.7118  30.878789               二層         十三層     2     0     2
# 1      234202.7068  59.350563             二十四層         三十層    24     0     2
# 2      103878.1534  24.066766               二層          二層     2     1     2
# 3      110000.4950  73.568000                全          二層   NaN     2     4
# 4       99940.9456  80.047632                全          二層   NaN     2     6
#
#    lr  bath  partition  mgmt  min_inci   min_hos   min_mrt  min_mart  \
# 0   1     2          1     1  3.216651  2.360415  6.347960  0.421408
# 1   2     2          1     1  8.482000  1.320465  0.893130  0.957701
# 2   1     1          1     0  2.242399  3.157690  7.202395  1.384427
# 3   2     2          1     0  2.096059  3.258152  7.277277  1.657483
# 4   2     2          1     0  2.094389  3.259394  7.277268  1.665824
#
#     min_gas  min_school  min_park yearMonth
# 0  0.259130    0.311712  0.082275    101-11
# 1  0.794212    0.069713  0.854684    102-02
# 2  1.237124    1.259014  0.942919    103-12
# 3  1.468159    1.413863  1.211620    104-09
# 4  1.474884    1.416363  1.219951    109-09

# %%
house.columns
# Out:
# Index(['id', 'section', 'parking_space', 'construction_time', 'trade_time',
#        'age', 'unit_price_ping', 'area', 'trasaction_floor', 'total_floor',
#        'floor', 'type', 'room', 'lr', 'bath', 'partition', 'mgmt', 'min_inci',
#        'min_hos', 'min_mrt', 'min_mart', 'min_gas', 'min_school', 'min_park',
#        'yearMonth'],
#       dtype='object')

# %%
house.isna().sum()
# Out:
# id                       0
# section                  0
# parking_space            0
# construction_time        0
# trade_time               0
# age                      0
# unit_price_ping          0
# area                     0
# trasaction_floor       126
# total_floor             58
# floor                32246
# type                     0
# room                     0
# lr                       0
# bath                     0
# partition                0
# mgmt                     0
# min_inci                 0
# min_hos                  0
# min_mrt                  0
# min_mart                 0
# min_gas                  0
# min_school               0
# min_park                 0
# yearMonth                0
# dtype: int64

# %%
# house為篩掉透天 type = 2
house = house[house.type != 2]

# %%
house.isna().sum()
# Out:
# id                       0
# section                  0
# parking_space            0
# construction_time        0
# trade_time               0
# age                      0
# unit_price_ping          0
# area                     0
# trasaction_floor       126
# total_floor             48
# floor                25404
# type                     0
# room                     0
# lr                       0
# bath                     0
# partition                0
# mgmt                     0
# min_inci                 0
# min_hos                  0
# min_mrt                  0
# min_mart                 0
# min_gas                  0
# min_school               0
# min_park                 0
# yearMonth                0
# dtype: int64

# %%
house.floor.unique()
# Out:
# array(['2', '24', '7', '13', '3', '4', nan, '14', '15', '17', '5', '16',
#        '12', '11', '6', '8', '10', '9', '18', '20', '19', '21', '22',
#        '23', '25', '26', '28', '27', '29', '30', '1', 'B1', 'check', '34',
#        '33', '31', '35', '32', '37', '41', '39', '38', '36', '40', '42',
#        '43', '45'], dtype=object)

# %%
pd.set_option("display.max_columns", None)

# %%
house.shape
# Out:
# (226781, 25)

# %%
# 拿掉floor&transaction_floor = nan
house = house[~(house.floor.isna() & house.trasaction_floor.isna())]

# %%
house.shape
# Out:
# (226771, 25)

# %% [markdown]
# # Deal with floor B1

# %%
# B1、chech、nan  pd.set_option("display.max_columns", None)
houseB1 = house[house.floor == 'B1']

# %%
houseB1
# Out:
#             id  section  parking_space  construction_time  trade_time  age  \
# 4532      5119        2              1             860809     1051025   19
# 4533      5120        2              1             860809     1020505   15
# 38860    56405        6              0             841021     1020925   17
# 40307    58132        6              1             830221     1010716   18
# 67445   108909       10              1             850509     1021121   17
# 67457   108921       10              0             850509     1031125   18
# 72764   117412        9              0             720518     1080328   35
# 85600   134681       14              1             860120     1061025   20
# 90139   140528       14              0             790321     1040421   25
# 107367  166959        7              0             791221     1080214   28
# 172298  263104       23              0             790226     1040601   25
# 182911  278506       24              1             840920     1030606   18
# 185674  282087       24              0             950303     1051103   10
# 185675  282088       24              0             950303     1040828    9
# 185676  282089       24              0             950303     1040827    9
# 185677  282090       24              0             950303     1031218    8
# 185678  282091       24              0             950303     1031214    8
# 185679  282092       24              0             950303     1021028    7
# 187117  285029       24              0             740114     1050608   31
# 187619  285563       24              1             840912     1090217   24
# 187620  285565       24              1             850919     1081024   23
# 187624  285569       24              1             850919     1090110   23
# 187626  285571       24              1             850919     1070723   21
# 187629  285574       24              1             850919     1081122   23
# 187630  285575       24              1             850919     1090218   23
# 187631  285576       24              1             850919     1020109   16
# 188350  286532       24              0             730820     1060422   32
# 188351  286533       24              0             730820     1050731   31
# 188352  286534       24              0             730820     1021113   29
# 191246  289843       24              1             991231     1040625    4
# 191249  289846       24              1             991231     1070307    7
# 191251  289849       24              1             991231     1070730    7
# 210957  328804       20              0             821014     1020308   19
# 222525  349766        4              1             901003     1060520   15
# 223350  350810        4              1             821224     1021118   19
#
#         unit_price_ping       area trasaction_floor total_floor floor  type  \
# 4532         67058.1530  45.483116               四層          七層    B1     3
# 4533         47269.6342  45.483950               三層          七層    B1     3
# 38860       343019.7254  28.132620              十二層         十四層    B1     0
# 40307       138625.4172  31.018980               四層          七層    B1     3
# 67445       230143.1844  23.029250             地下一層         十一層    B1     0
# 67457       278057.4496  21.038910             地下一層         十一層    B1     0
# 72764       160665.1858  74.689820              地下層          五層    B1     1
# 85600       197538.0790  37.461300             地下一層         十二層    B1     0
# 90139       320094.0024  18.119760             地下一層          五層    B1     1
# 107367      261445.8046  50.871190               八層         十四層    B1     0
# 172298      143894.8624  55.596400             地下一層          四層    B1     1
# 182911      296850.9226  26.949680               八層         十二層    B1     0
# 185674      237885.3680  37.413150               八層          九層    B1     3
# 185675      226572.9204  28.026420               二層          九層    B1     3
# 185676      237369.6632  37.410170               七層          九層    B1     3
# 185677      240576.2892  37.410340               二層          九層    B1     3
# 185678      272801.2276  36.656890               三層          九層    B1     3
# 185679      267604.5100  28.026560               八層          九層    B1     3
# 187117       85831.7912  19.223730             地下一層          九層    B1     3
# 187619      322831.2048  29.427280             地下一層          二層    B1     1
# 187620      194906.6622  32.836380             地下一層          二層    B1     1
# 187624      253789.5718  27.582030             地下一層          二層    B1     1
# 187626      278526.8732  27.645570             地下一層          二層    B1     1
# 187629      259667.2842  24.184900             地下一層          二層    B1     1
# 187630      288077.3294  21.174970             地下一層          二層    B1     1
# 187631      250295.3412  21.175080             地下一層          二層    B1     1
# 188350      129038.5972  33.323510             地下一層          五層    B1     1
# 188351      135041.9300  33.323130             地下一層          五層    B1     1
# 188352       85226.8298  33.322990             地下一層          五層    B1     1
# 191246      263528.4586  68.304130             地下一層          七層    B1     3
# 191249      219799.3362  22.748120             地下一層          七層    B1     4
# 191251      209584.4142  24.811120             地下一層          七層    B1     3
# 210957      316183.2410  32.576190               二層          七層    B1     3
# 222525      295912.0754  43.932170               六層          七層    B1     3
# 223350      264146.6432  62.844160              十二層         十六層    B1     0
#
#         room  lr  bath  partition  mgmt   min_inci   min_hos    min_mrt  \
# 4532       3   2     2          1     1  19.483559  5.514346  12.314500
# 4533       3   2     2          1     1  19.483559  5.514346  12.314500
# 38860      3   2     2          1     1   2.326405  1.407056   1.809721
# 40307      3   2     2          1     1   5.227311  1.350790   1.303662
# 67445      1   2     1          1     1   8.473754  4.194260   2.611891
# 67457      4   2     2          1     1   8.477544  4.188529   2.614895
# 72764      9   0     9          1     1   5.564977  0.205371   0.452591
# 85600      3   2     2          1     1  16.655979  4.497845   2.558868
# 90139      2   2     1          1     1  18.474145  2.740261   2.306959
# 107367     4   2     2          1     1   3.515640  1.539040   1.363047
# 172298     6   0     6          1     0  11.343119  6.442291   1.919465
# 182911     2   2     1          1     1   2.819801  1.784338   1.215920
# 185674     3   2     2          1     1   1.321320  1.666701   4.235237
# 185675     3   2     2          1     1   1.321320  1.666701   4.235237
# 185676     3   2     2          1     1   1.321320  1.666701   4.235237
# 185677     3   2     2          1     1   1.321320  1.666701   4.235237
# 185678     4   2     2          1     1   1.321320  1.666701   4.235237
# 185679     2   2     2          1     1   1.321320  1.666701   4.235237
# 187117     1   1     1          1     1   7.103636  6.167679   6.264354
# 187619     3   2     1          1     1   6.162203  4.756941   3.846010
# 187620     2   2     1          1     1   6.206852  4.800043   3.871895
# 187624     3   2     2          1     0   6.264994  4.859778   3.921996
# 187626     2   1     1          1     1   6.266793  4.859572   3.914411
# 187629     2   2     2          1     1   6.228357  4.819324   3.877836
# 187630     3   1     2          1     1   6.234821  4.825150   3.879766
# 187631     3   2     1          1     1   6.234821  4.825150   3.879766
# 188350     3   2     1          1     1   1.210778  1.032080   4.582121
# 188351     2   2     1          1     1   1.210778  1.032080   4.582121
# 188352     3   2     1          1     0   1.210778  1.032080   4.582121
# 191246     3   2     2          1     1   7.155227  6.180645   6.188425
# 191249     1   1     1          1     1   7.152699  6.179617   6.190982
# 191251     1   1     1          1     0   7.151482  6.174585   6.178066
# 210957     3   1     2          1     1   3.900352  0.265605   0.563846
# 222525     3   2     2          1     1   9.517897  1.484958   0.760400
# 223350     3   2     2          1     1   9.068421  0.917205   0.585833
#
#         min_mart   min_gas  min_school  min_park yearMonth
# 4532    9.909817  0.496748    0.426333  0.449979    105-10
# 4533    9.909817  0.496748    0.426333  0.449979    102-05
# 38860   0.242592  0.628762    0.107545  0.273438    102-09
# 40307   1.963475  1.307411    0.460793  0.886217    101-07
# 67445   0.213632  0.438595    0.364502  0.313468    102-11
# 67457   0.211791  0.438545    0.356592  0.316668    103-11
# 72764   0.242423  0.810509    0.262689  0.088528    108-03
# 85600   2.588421  1.758960    1.778721  0.982623    106-10
# 90139   0.363195  0.414713    0.308494  0.464919    104-04
# 107367  0.451005  0.182891    0.507709  0.386686    108-02
# 172298  0.662157  0.534457    2.043064  1.979002    104-06
# 182911  0.652745  0.076619    0.237153  0.085578    103-06
# 185674  0.464960  1.809131    1.163503  2.628036    105-11
# 185675  0.464960  1.809131    1.163503  2.628036    104-08
# 185676  0.464960  1.809131    1.163503  2.628036    104-08
# 185677  0.464960  1.809131    1.163503  2.628036    103-12
# 185678  0.464960  1.809131    1.163503  2.628036    103-12
# 185679  0.464960  1.809131    1.163503  2.628036    102-10
# 187117  4.778148  0.679523    2.514484  4.504310    105-06
# 187619  2.121088  2.010720    0.157770  1.924271    109-02
# 187620  2.130288  2.006371    0.158036  1.944042    108-10
# 187624  2.163927  1.980832    0.156342  1.988812    109-01
# 187626  2.153300  1.992372    0.168159  1.979971    107-07
# 187629  2.126542  2.013505    0.171602  1.946389    108-11
# 187630  2.125621  2.015544    0.175980  1.947285    109-02
# 187631  2.125621  2.015544    0.175980  1.947285    102-01
# 188350  0.120912  1.303618    0.113493  2.024273    106-04
# 188351  0.120912  1.303618    0.113493  2.024273    105-07
# 188352  0.120912  1.303618    0.113493  2.024273    102-11
# 191246  4.659294  0.534590    2.386658  4.401105    104-06
# 191249  4.663617  0.539546    2.391284  4.404761    107-03
# 191251  4.647544  0.522523    2.374737  4.389811    107-07
# 210957  0.245292  0.361091    0.355733  0.590890    102-03
# 222525  0.536261  1.062930    0.253129  0.483588    106-05
# 223350  0.517873  0.603000    0.231757  0.161665    102-11

# %%
houseB1.trasaction_floor.unique()
# Out:
# array(['四層', '三層', '十二層', '地下一層', '地下層', '八層', '二層', '七層', '六層'],
#       dtype=object)

# %%
houseB1.floor = house.trasaction_floor.map({'地下層': -1, '地下一層': -1, '二層': 2, '三層': 3, '四層': 4, '六層': 6, '七層': 7, '八層': 8, '十二層': 12})
# Out:
# e:\program\python\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
houseB1
# Out:
#             id  section  parking_space  construction_time  trade_time  age  \
# 4532      5119        2              1             860809     1051025   19
# 4533      5120        2              1             860809     1020505   15
# 38860    56405        6              0             841021     1020925   17
# 40307    58132        6              1             830221     1010716   18
# 67445   108909       10              1             850509     1021121   17
# 67457   108921       10              0             850509     1031125   18
# 72764   117412        9              0             720518     1080328   35
# 85600   134681       14              1             860120     1061025   20
# 90139   140528       14              0             790321     1040421   25
# 107367  166959        7              0             791221     1080214   28
# 172298  263104       23              0             790226     1040601   25
# 182911  278506       24              1             840920     1030606   18
# 185674  282087       24              0             950303     1051103   10
# 185675  282088       24              0             950303     1040828    9
# 185676  282089       24              0             950303     1040827    9
# 185677  282090       24              0             950303     1031218    8
# 185678  282091       24              0             950303     1031214    8
# 185679  282092       24              0             950303     1021028    7
# 187117  285029       24              0             740114     1050608   31
# 187619  285563       24              1             840912     1090217   24
# 187620  285565       24              1             850919     1081024   23
# 187624  285569       24              1             850919     1090110   23
# 187626  285571       24              1             850919     1070723   21
# 187629  285574       24              1             850919     1081122   23
# 187630  285575       24              1             850919     1090218   23
# 187631  285576       24              1             850919     1020109   16
# 188350  286532       24              0             730820     1060422   32
# 188351  286533       24              0             730820     1050731   31
# 188352  286534       24              0             730820     1021113   29
# 191246  289843       24              1             991231     1040625    4
# 191249  289846       24              1             991231     1070307    7
# 191251  289849       24              1             991231     1070730    7
# 210957  328804       20              0             821014     1020308   19
# 222525  349766        4              1             901003     1060520   15
# 223350  350810        4              1             821224     1021118   19
#
#         unit_price_ping       area trasaction_floor total_floor  floor  type  \
# 4532         67058.1530  45.483116               四層          七層    4.0     3
# 4533         47269.6342  45.483950               三層          七層    3.0     3
# 38860       343019.7254  28.132620              十二層         十四層   12.0     0
# 40307       138625.4172  31.018980               四層          七層    4.0     3
# 67445       230143.1844  23.029250             地下一層         十一層   -1.0     0
# 67457       278057.4496  21.038910             地下一層         十一層   -1.0     0
# 72764       160665.1858  74.689820              地下層          五層   -1.0     1
# 85600       197538.0790  37.461300             地下一層         十二層   -1.0     0
# 90139       320094.0024  18.119760             地下一層          五層   -1.0     1
# 107367      261445.8046  50.871190               八層         十四層    8.0     0
# 172298      143894.8624  55.596400             地下一層          四層   -1.0     1
# 182911      296850.9226  26.949680               八層         十二層    8.0     0
# 185674      237885.3680  37.413150               八層          九層    8.0     3
# 185675      226572.9204  28.026420               二層          九層    2.0     3
# 185676      237369.6632  37.410170               七層          九層    7.0     3
# 185677      240576.2892  37.410340               二層          九層    2.0     3
# 185678      272801.2276  36.656890               三層          九層    3.0     3
# 185679      267604.5100  28.026560               八層          九層    8.0     3
# 187117       85831.7912  19.223730             地下一層          九層   -1.0     3
# 187619      322831.2048  29.427280             地下一層          二層   -1.0     1
# 187620      194906.6622  32.836380             地下一層          二層   -1.0     1
# 187624      253789.5718  27.582030             地下一層          二層   -1.0     1
# 187626      278526.8732  27.645570             地下一層          二層   -1.0     1
# 187629      259667.2842  24.184900             地下一層          二層   -1.0     1
# 187630      288077.3294  21.174970             地下一層          二層   -1.0     1
# 187631      250295.3412  21.175080             地下一層          二層   -1.0     1
# 188350      129038.5972  33.323510             地下一層          五層   -1.0     1
# 188351      135041.9300  33.323130             地下一層          五層   -1.0     1
# 188352       85226.8298  33.322990             地下一層          五層   -1.0     1
# 191246      263528.4586  68.304130             地下一層          七層   -1.0     3
# 191249      219799.3362  22.748120             地下一層          七層   -1.0     4
# 191251      209584.4142  24.811120             地下一層          七層   -1.0     3
# 210957      316183.2410  32.576190               二層          七層    2.0     3
# 222525      295912.0754  43.932170               六層          七層    6.0     3
# 223350      264146.6432  62.844160              十二層         十六層   12.0     0
#
#         room  lr  bath  partition  mgmt   min_inci   min_hos    min_mrt  \
# 4532       3   2     2          1     1  19.483559  5.514346  12.314500
# 4533       3   2     2          1     1  19.483559  5.514346  12.314500
# 38860      3   2     2          1     1   2.326405  1.407056   1.809721
# 40307      3   2     2          1     1   5.227311  1.350790   1.303662
# 67445      1   2     1          1     1   8.473754  4.194260   2.611891
# 67457      4   2     2          1     1   8.477544  4.188529   2.614895
# 72764      9   0     9          1     1   5.564977  0.205371   0.452591
# 85600      3   2     2          1     1  16.655979  4.497845   2.558868
# 90139      2   2     1          1     1  18.474145  2.740261   2.306959
# 107367     4   2     2          1     1   3.515640  1.539040   1.363047
# 172298     6   0     6          1     0  11.343119  6.442291   1.919465
# 182911     2   2     1          1     1   2.819801  1.784338   1.215920
# 185674     3   2     2          1     1   1.321320  1.666701   4.235237
# 185675     3   2     2          1     1   1.321320  1.666701   4.235237
# 185676     3   2     2          1     1   1.321320  1.666701   4.235237
# 185677     3   2     2          1     1   1.321320  1.666701   4.235237
# 185678     4   2     2          1     1   1.321320  1.666701   4.235237
# 185679     2   2     2          1     1   1.321320  1.666701   4.235237
# 187117     1   1     1          1     1   7.103636  6.167679   6.264354
# 187619     3   2     1          1     1   6.162203  4.756941   3.846010
# 187620     2   2     1          1     1   6.206852  4.800043   3.871895
# 187624     3   2     2          1     0   6.264994  4.859778   3.921996
# 187626     2   1     1          1     1   6.266793  4.859572   3.914411
# 187629     2   2     2          1     1   6.228357  4.819324   3.877836
# 187630     3   1     2          1     1   6.234821  4.825150   3.879766
# 187631     3   2     1          1     1   6.234821  4.825150   3.879766
# 188350     3   2     1          1     1   1.210778  1.032080   4.582121
# 188351     2   2     1          1     1   1.210778  1.032080   4.582121
# 188352     3   2     1          1     0   1.210778  1.032080   4.582121
# 191246     3   2     2          1     1   7.155227  6.180645   6.188425
# 191249     1   1     1          1     1   7.152699  6.179617   6.190982
# 191251     1   1     1          1     0   7.151482  6.174585   6.178066
# 210957     3   1     2          1     1   3.900352  0.265605   0.563846
# 222525     3   2     2          1     1   9.517897  1.484958   0.760400
# 223350     3   2     2          1     1   9.068421  0.917205   0.585833
#
#         min_mart   min_gas  min_school  min_park yearMonth
# 4532    9.909817  0.496748    0.426333  0.449979    105-10
# 4533    9.909817  0.496748    0.426333  0.449979    102-05
# 38860   0.242592  0.628762    0.107545  0.273438    102-09
# 40307   1.963475  1.307411    0.460793  0.886217    101-07
# 67445   0.213632  0.438595    0.364502  0.313468    102-11
# 67457   0.211791  0.438545    0.356592  0.316668    103-11
# 72764   0.242423  0.810509    0.262689  0.088528    108-03
# 85600   2.588421  1.758960    1.778721  0.982623    106-10
# 90139   0.363195  0.414713    0.308494  0.464919    104-04
# 107367  0.451005  0.182891    0.507709  0.386686    108-02
# 172298  0.662157  0.534457    2.043064  1.979002    104-06
# 182911  0.652745  0.076619    0.237153  0.085578    103-06
# 185674  0.464960  1.809131    1.163503  2.628036    105-11
# 185675  0.464960  1.809131    1.163503  2.628036    104-08
# 185676  0.464960  1.809131    1.163503  2.628036    104-08
# 185677  0.464960  1.809131    1.163503  2.628036    103-12
# 185678  0.464960  1.809131    1.163503  2.628036    103-12
# 185679  0.464960  1.809131    1.163503  2.628036    102-10
# 187117  4.778148  0.679523    2.514484  4.504310    105-06
# 187619  2.121088  2.010720    0.157770  1.924271    109-02
# 187620  2.130288  2.006371    0.158036  1.944042    108-10
# 187624  2.163927  1.980832    0.156342  1.988812    109-01
# 187626  2.153300  1.992372    0.168159  1.979971    107-07
# 187629  2.126542  2.013505    0.171602  1.946389    108-11
# 187630  2.125621  2.015544    0.175980  1.947285    109-02
# 187631  2.125621  2.015544    0.175980  1.947285    102-01
# 188350  0.120912  1.303618    0.113493  2.024273    106-04
# 188351  0.120912  1.303618    0.113493  2.024273    105-07
# 188352  0.120912  1.303618    0.113493  2.024273    102-11
# 191246  4.659294  0.534590    2.386658  4.401105    104-06
# 191249  4.663617  0.539546    2.391284  4.404761    107-03
# 191251  4.647544  0.522523    2.374737  4.389811    107-07
# 210957  0.245292  0.361091    0.355733  0.590890    102-03
# 222525  0.536261  1.062930    0.253129  0.483588    106-05
# 223350  0.517873  0.603000    0.231757  0.161665    102-11

# %%
house_without_B1 = house[~(house.floor == 'B1')]

# %%
house = pd.concat([house_without_B1, houseB1])

# %%
house.floor.unique()
# Out:
# array([2, 4, 7, 3, nan, 6, '5', 8, '10', '11', '9', '15', '6', '7', '12',
#        '3', '2', '4', '8', '14', '13', '16', '18', '17', '20', '19', '21',
#        '22', '23', '24', '25', '26', '28', '27', '29', '30', '1', 'check',
#        '34', '33', '31', '35', '32', '37', '41', '39', '38', '36', '40',
#        '42', '43', '45', 12.0, -1.0], dtype=object)

# %%
house.shape
# Out:
# (226781, 25)

# %% [markdown]
# # Deal with floor check

# %%
house_check = house[house.floor == 'check']

# %%
house_check
# Out:
#             id  section  parking_space  construction_time  trade_time  age  \
# 4847      5456        2              1             820709     1010815   19
# 6239      6953        2              0             850601     1040612   19
# 13249    16193        3              0             590211     1020325   43
# 13501    16471        3              0             680117     1020826   34
# 14736    18104        3              0             700303     1031231   33
# 38099    55359        6              0             680111     1090303   41
# 66266   101123       10              0             641101     1021226   38
# 77924   124641       14              0             840126     1020123   17
# 79585   126441       14              0             720718     1100310   37
# 81692   129667       14              0             740302     1060120   31
# 82897   131001       14              0             681029     1021022   33
# 109622  169658        7              0             670705     1071120   40
# 117647  184736       18              1             970111     1020603    5
# 125325  209265       15              0             660624     1020422   35
# 127075  212028       19              0             680907     1051116   37
# 127078  212031       19              0             680907     1021224   34
# 134204  220807       22              0             920922     1020109    9
# 134205  220808       22              1             920922     1020406    9
# 140638  228914       22              1             840727     1030725   18
# 140716  228994       22              1             801022     1060427   25
# 171247  261689       22              1            1021007     1021106    0
# 174104  265096       24              1             930721     1020406    8
# 183617  279439       24              0             740509     1011123   27
# 184150  280044       24              0             781227     1020925   23
# 194907  293912       24              0             780404     1041022   26
# 194908  293913       24              0             780404     1020425   24
# 194911  293916       24              0             780404     1020827   24
# 230169  358780        4              1             810522     1050828   24
#
#         unit_price_ping        area trasaction_floor total_floor  floor  type  \
# 4847         57715.9622   52.845237               二層          七層  check     3
# 6239         69557.3378   30.909890               八層         十三層  check     4
# 13249       136407.2254   18.041098               二層          三層  check     1
# 13501       275482.2314   65.340261               三層          四層  check     1
# 14736       607963.0664   26.317507               二層          三層  check     1
# 38099       217141.4730   66.546780            陽台，二層          四層  check     1
# 66266       106615.3558   38.925150            二層，三層          三層  check     1
# 77924       305670.7970   17.142700              十一層        二十四層  check     0
# 79585       136023.7526   22.055070              地下層          五層  check     1
# 81692       364034.6960   21.701330              地下層          五層  check     1
# 82897       150013.8982   54.661850               二層          三層  check     1
# 109622      467985.5770   45.493060            一層，平台          四層  check     1
# 117647      198923.2092   49.265460               四層         十五層  check     0
# 125325      290606.2664   29.593440            一層，騎樓          三層  check     1
# 127075      178209.0664   19.078800           平台，地下層          四層  check     1
# 127078      117934.4150   19.078490           平台，地下層          四層  check     1
# 134204      298368.2848   15.584840             二十五層        二十六層  check     4
# 134205      365033.0476   57.529300              十六層        二十五層  check     0
# 140638      168813.9828   75.231070              十四層         十九層  check     0
# 140716      151756.0548   44.808960               二層          六層  check     3
# 171247      222000.9990   43.468470               八層         十三層  check     0
# 174104      448993.7560  100.224600               二層          六層  check     3
# 183617       85428.4836   51.575540               二層          五層  check     1
# 184150      192939.7112   32.134530               四層          四層  check     1
# 194907      371836.3840   30.927720         一層，二層，夾層          五層  check     1
# 194908      355671.0220   30.927600         一層，二層，夾層          五層  check     1
# 194911      352437.9496   30.927570         一層，二層，夾層          五層  check     1
# 230169      268126.8264   27.524410         二層，電梯樓梯間          七層  check     3
#
#         room  lr  bath  partition  mgmt   min_inci   min_hos    min_mrt  \
# 4847       4   2     2          1     1  18.930154  5.199957  11.888783
# 6239       2   0     2          1     1  18.227228  5.609423  11.809661
# 13249      3   2     2          1     0   8.356747  1.522820   0.584686
# 13501     10   4     2          1     0   8.194681  0.842355   0.418583
# 14736      3   3     3          1     0   7.160806  0.584492   0.403232
# 38099      9   8     5          1     0   3.390204  0.853614   0.504900
# 66266      3   1     3          1     0   9.197421  3.353424   2.106602
# 77924      1   1     1          1     1  19.843972  1.041186   3.862888
# 79585      2   1     1          1     0  20.362075  0.535896   4.335391
# 81692      3   1     1          1     0  15.811528  5.070572   0.945866
# 82897      1   1     1          1     0  20.239541  2.497626   4.177062
# 109622     2   2     2          1     0   1.473344  0.992005   1.023276
# 117647     3   2     2          1     1   5.681916  7.401891   2.684360
# 125325     2   2     3          1     0  28.903097  0.938489  15.611037
# 127075     2   1     1          1     0   5.715134  1.723685   1.336151
# 127078     2   1     1          1     0   5.712459  1.722718   1.332074
# 134204     1   1     1          1     1   9.656167  1.788997   0.151715
# 134205     3   2     1          1     1   9.656167  1.788997   0.151715
# 140638     4   2     2          1     1   7.773517  2.646300   4.805124
# 140716     3   2     2          1     1   7.811875  2.533528   4.694853
# 171247     3   1     2          1     1   8.808681  2.321147   5.181340
# 174104     5   3     4          1     0   3.640677  0.788070   0.249209
# 183617     5   2     3          1     0   1.640844  0.322083   2.161614
# 184150     4   1     2          1     0   0.462068  0.282917   3.914161
# 194907     3   2     3          1     1   5.699507  1.622411   0.876164
# 194908     4   2     3          1     1   5.699507  1.622411   0.876164
# 194911     3   2     2          1     1   5.675763  1.602952   0.858290
# 230169     2   2     1          1     1   9.131267  1.097262   1.057879
#
#         min_mart   min_gas  min_school  min_park yearMonth
# 4847    9.385455  0.696177    0.170032  0.163915    101-08
# 6239    8.909752  1.659905    1.396403  0.769929    104-06
# 13249   0.123567  0.163831    0.714836  0.229312    102-03
# 13501   0.351560  0.656144    0.365882  0.105988    102-08
# 14736   0.382903  0.722409    0.660064  0.320693    103-12
# 38099   0.601933  0.081277    0.234964  0.186787    109-03
# 66266   0.635615  0.464589    0.819256  0.249448    102-12
# 77924   0.051051  0.329460    0.296014  0.541232    102-01
# 79585   0.532315  0.313184    0.233382  0.184362    110-03
# 81692   2.419771  0.987798    0.112889  0.207037    106-01
# 82897   2.503968  2.437187    2.195227  1.617105    102-10
# 109622  0.478341  1.102216    0.584200  0.185877    107-11
# 117647  0.862046  0.165653    0.569857  0.136905    102-06
# 125325  0.258733  0.418855    0.189817  0.109771    102-04
# 127075  0.248633  1.884158    0.491152  0.527476    105-11
# 127078  0.254256  1.889470    0.485600  0.522132    102-12
# 134204  1.958523  1.178041    0.161289  0.097283    102-01
# 134205  1.958523  1.178041    0.161289  0.097283    102-04
# 140638  0.133850  2.560403    0.063706  0.108219    103-07
# 140716  0.089945  2.488858    0.164128  0.151918    106-04
# 171247  1.008800  1.869530    0.970428  0.323614    102-11
# 174104  0.085133  0.855109    0.170948  0.321053    102-04
# 183617  0.103909  0.561524    0.035149  0.299082    101-11
# 184150  0.820488  0.554040    0.480212  1.379095    102-09
# 194907  0.701373  0.626234    0.540894  0.694072    104-10
# 194908  0.701373  0.626234    0.540894  0.694072    102-04
# 194911  0.691356  0.626462    0.517754  0.683146    102-08
# 230169  0.343789  1.058873    0.370705  0.193691    105-08

# %%
house_check.trasaction_floor.unique()
# Out:
# array(['二層', '八層', '三層', '陽台，二層', '二層，三層', '十一層', '地下層', '一層，平台', '四層',
#        '一層，騎樓', '平台，地下層', '二十五層', '十六層', '十四層', '一層，二層，夾層', '二層，電梯樓梯間'],
#       dtype=object)

# %%
house_check.floor = house_check.trasaction_floor.map({'二層': 2, '八層': 8, '三層': 3, '陽台，二層': 2, '二層，三層': 3, '十一層': 11, '地下層': -1, '一層，平台': 1, '四層': 4,
       '一層，騎樓': 1, '平台，地下層': -1, '二十五層': 25, '十六層': 16, '十四層': 14, '一層，二層，夾層': 2, '二層，電梯樓梯間': 2})
# Out:
# e:\program\python\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
house_check
# Out:
#             id  section  parking_space  construction_time  trade_time  age  \
# 4847      5456        2              1             820709     1010815   19
# 6239      6953        2              0             850601     1040612   19
# 13249    16193        3              0             590211     1020325   43
# 13501    16471        3              0             680117     1020826   34
# 14736    18104        3              0             700303     1031231   33
# 38099    55359        6              0             680111     1090303   41
# 66266   101123       10              0             641101     1021226   38
# 77924   124641       14              0             840126     1020123   17
# 79585   126441       14              0             720718     1100310   37
# 81692   129667       14              0             740302     1060120   31
# 82897   131001       14              0             681029     1021022   33
# 109622  169658        7              0             670705     1071120   40
# 117647  184736       18              1             970111     1020603    5
# 125325  209265       15              0             660624     1020422   35
# 127075  212028       19              0             680907     1051116   37
# 127078  212031       19              0             680907     1021224   34
# 134204  220807       22              0             920922     1020109    9
# 134205  220808       22              1             920922     1020406    9
# 140638  228914       22              1             840727     1030725   18
# 140716  228994       22              1             801022     1060427   25
# 171247  261689       22              1            1021007     1021106    0
# 174104  265096       24              1             930721     1020406    8
# 183617  279439       24              0             740509     1011123   27
# 184150  280044       24              0             781227     1020925   23
# 194907  293912       24              0             780404     1041022   26
# 194908  293913       24              0             780404     1020425   24
# 194911  293916       24              0             780404     1020827   24
# 230169  358780        4              1             810522     1050828   24
#
#         unit_price_ping        area trasaction_floor total_floor  floor  type  \
# 4847         57715.9622   52.845237               二層          七層      2     3
# 6239         69557.3378   30.909890               八層         十三層      8     4
# 13249       136407.2254   18.041098               二層          三層      2     1
# 13501       275482.2314   65.340261               三層          四層      3     1
# 14736       607963.0664   26.317507               二層          三層      2     1
# 38099       217141.4730   66.546780            陽台，二層          四層      2     1
# 66266       106615.3558   38.925150            二層，三層          三層      3     1
# 77924       305670.7970   17.142700              十一層        二十四層     11     0
# 79585       136023.7526   22.055070              地下層          五層     -1     1
# 81692       364034.6960   21.701330              地下層          五層     -1     1
# 82897       150013.8982   54.661850               二層          三層      2     1
# 109622      467985.5770   45.493060            一層，平台          四層      1     1
# 117647      198923.2092   49.265460               四層         十五層      4     0
# 125325      290606.2664   29.593440            一層，騎樓          三層      1     1
# 127075      178209.0664   19.078800           平台，地下層          四層     -1     1
# 127078      117934.4150   19.078490           平台，地下層          四層     -1     1
# 134204      298368.2848   15.584840             二十五層        二十六層     25     4
# 134205      365033.0476   57.529300              十六層        二十五層     16     0
# 140638      168813.9828   75.231070              十四層         十九層     14     0
# 140716      151756.0548   44.808960               二層          六層      2     3
# 171247      222000.9990   43.468470               八層         十三層      8     0
# 174104      448993.7560  100.224600               二層          六層      2     3
# 183617       85428.4836   51.575540               二層          五層      2     1
# 184150      192939.7112   32.134530               四層          四層      4     1
# 194907      371836.3840   30.927720         一層，二層，夾層          五層      2     1
# 194908      355671.0220   30.927600         一層，二層，夾層          五層      2     1
# 194911      352437.9496   30.927570         一層，二層，夾層          五層      2     1
# 230169      268126.8264   27.524410         二層，電梯樓梯間          七層      2     3
#
#         room  lr  bath  partition  mgmt   min_inci   min_hos    min_mrt  \
# 4847       4   2     2          1     1  18.930154  5.199957  11.888783
# 6239       2   0     2          1     1  18.227228  5.609423  11.809661
# 13249      3   2     2          1     0   8.356747  1.522820   0.584686
# 13501     10   4     2          1     0   8.194681  0.842355   0.418583
# 14736      3   3     3          1     0   7.160806  0.584492   0.403232
# 38099      9   8     5          1     0   3.390204  0.853614   0.504900
# 66266      3   1     3          1     0   9.197421  3.353424   2.106602
# 77924      1   1     1          1     1  19.843972  1.041186   3.862888
# 79585      2   1     1          1     0  20.362075  0.535896   4.335391
# 81692      3   1     1          1     0  15.811528  5.070572   0.945866
# 82897      1   1     1          1     0  20.239541  2.497626   4.177062
# 109622     2   2     2          1     0   1.473344  0.992005   1.023276
# 117647     3   2     2          1     1   5.681916  7.401891   2.684360
# 125325     2   2     3          1     0  28.903097  0.938489  15.611037
# 127075     2   1     1          1     0   5.715134  1.723685   1.336151
# 127078     2   1     1          1     0   5.712459  1.722718   1.332074
# 134204     1   1     1          1     1   9.656167  1.788997   0.151715
# 134205     3   2     1          1     1   9.656167  1.788997   0.151715
# 140638     4   2     2          1     1   7.773517  2.646300   4.805124
# 140716     3   2     2          1     1   7.811875  2.533528   4.694853
# 171247     3   1     2          1     1   8.808681  2.321147   5.181340
# 174104     5   3     4          1     0   3.640677  0.788070   0.249209
# 183617     5   2     3          1     0   1.640844  0.322083   2.161614
# 184150     4   1     2          1     0   0.462068  0.282917   3.914161
# 194907     3   2     3          1     1   5.699507  1.622411   0.876164
# 194908     4   2     3          1     1   5.699507  1.622411   0.876164
# 194911     3   2     2          1     1   5.675763  1.602952   0.858290
# 230169     2   2     1          1     1   9.131267  1.097262   1.057879
#
#         min_mart   min_gas  min_school  min_park yearMonth
# 4847    9.385455  0.696177    0.170032  0.163915    101-08
# 6239    8.909752  1.659905    1.396403  0.769929    104-06
# 13249   0.123567  0.163831    0.714836  0.229312    102-03
# 13501   0.351560  0.656144    0.365882  0.105988    102-08
# 14736   0.382903  0.722409    0.660064  0.320693    103-12
# 38099   0.601933  0.081277    0.234964  0.186787    109-03
# 66266   0.635615  0.464589    0.819256  0.249448    102-12
# 77924   0.051051  0.329460    0.296014  0.541232    102-01
# 79585   0.532315  0.313184    0.233382  0.184362    110-03
# 81692   2.419771  0.987798    0.112889  0.207037    106-01
# 82897   2.503968  2.437187    2.195227  1.617105    102-10
# 109622  0.478341  1.102216    0.584200  0.185877    107-11
# 117647  0.862046  0.165653    0.569857  0.136905    102-06
# 125325  0.258733  0.418855    0.189817  0.109771    102-04
# 127075  0.248633  1.884158    0.491152  0.527476    105-11
# 127078  0.254256  1.889470    0.485600  0.522132    102-12
# 134204  1.958523  1.178041    0.161289  0.097283    102-01
# 134205  1.958523  1.178041    0.161289  0.097283    102-04
# 140638  0.133850  2.560403    0.063706  0.108219    103-07
# 140716  0.089945  2.488858    0.164128  0.151918    106-04
# 171247  1.008800  1.869530    0.970428  0.323614    102-11
# 174104  0.085133  0.855109    0.170948  0.321053    102-04
# 183617  0.103909  0.561524    0.035149  0.299082    101-11
# 184150  0.820488  0.554040    0.480212  1.379095    102-09
# 194907  0.701373  0.626234    0.540894  0.694072    104-10
# 194908  0.701373  0.626234    0.540894  0.694072    102-04
# 194911  0.691356  0.626462    0.517754  0.683146    102-08
# 230169  0.343789  1.058873    0.370705  0.193691    105-08

# %%
house_without_check = house[~(house.floor == 'check')]

# %%
house_without_check
# Out:
#             id  section  parking_space  construction_time  trade_time  age  \
# 0            2        1              0             820504     1011122   19
# 1            3        1              1             850923     1020204   16
# 2            6        1              0             700820     1031209   33
# 7           11        1              1             830625     1020512   18
# 8           12        1              1             841118     1020305   17
# ...        ...      ...            ...                ...         ...  ...
# 191249  289846       24              1             991231     1070307    7
# 191251  289849       24              1             991231     1070730    7
# 210957  328804       20              0             821014     1020308   19
# 222525  349766        4              1             901003     1060520   15
# 223350  350810        4              1             821224     1021118   19
#
#         unit_price_ping       area trasaction_floor total_floor floor  type  \
# 0           115937.7118  30.878789               二層         十三層     2     0
# 1           234202.7068  59.350563             二十四層         三十層     4     0
# 2           103878.1534  24.066766               二層          二層     2     1
# 7           137901.4470  52.211435               七層          八層     7     3
# 8           151964.3202  42.773391               二層          九層     2     3
# ...                 ...        ...              ...         ...   ...   ...
# 191249      219799.3362  22.748120             地下一層          七層  -1.0     4
# 191251      209584.4142  24.811120             地下一層          七層  -1.0     3
# 210957      316183.2410  32.576190               二層          七層   2.0     3
# 222525      295912.0754  43.932170               六層          七層   6.0     3
# 223350      264146.6432  62.844160              十二層         十六層  12.0     0
#
#         room  lr  bath  partition  mgmt  min_inci   min_hos   min_mrt  \
# 0          2   1     2          1     1  3.216651  2.360415  6.347960
# 1          2   2     2          1     1  8.482000  1.320465  0.893130
# 2          2   1     1          1     0  2.242399  3.157690  7.202395
# 7          3   2     2          1     1  9.659151  1.878537  3.856395
# 8          3   2     2          1     0  6.475433  6.703605  2.963666
# ...      ...  ..   ...        ...   ...       ...       ...       ...
# 191249     1   1     1          1     1  7.152699  6.179617  6.190982
# 191251     1   1     1          1     0  7.151482  6.174585  6.178066
# 210957     3   1     2          1     1  3.900352  0.265605  0.563846
# 222525     3   2     2          1     1  9.517897  1.484958  0.760400
# 223350     3   2     2          1     1  9.068421  0.917205  0.585833
#
#         min_mart   min_gas  min_school  min_park yearMonth
# 0       0.421408  0.259130    0.311712  0.082275    101-11
# 1       0.957701  0.794212    0.069713  0.854684    102-02
# 2       1.384427  1.237124    1.259014  0.942919    103-12
# 7       0.145219  0.636666    0.099600  0.051756    102-05
# 8       0.231109  0.862809    0.301156  0.328983    102-03
# ...          ...       ...         ...       ...       ...
# 191249  4.663617  0.539546    2.391284  4.404761    107-03
# 191251  4.647544  0.522523    2.374737  4.389811    107-07
# 210957  0.245292  0.361091    0.355733  0.590890    102-03
# 222525  0.536261  1.062930    0.253129  0.483588    106-05
# 223350  0.517873  0.603000    0.231757  0.161665    102-11
#
# [226753 rows x 25 columns]

# %%
index = na.trasaction_floor.reset_index(drop = True)

# %%
j = 0
for i in range(len(index)) :
    if len(index[i]) > 4 :
        print(index[i])
        j += 1
    else :
        continue
print(j)
# Out:
# 一層，夾層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，二層，三層，四層，屋頂突出物
# 一層，騎樓
# 三層，走廊
# 一層，二層，三層，屋頂突出物
# 一層，二層，三層，屋頂突出物
# 一層，二層
# 一層，平台
# 一層，平台
# 一層，走廊
# 一層，走廊
# 一層，騎樓
# 一層，走廊
# 二層，走廊
# 走廊，三層
# 一層，走廊
# 騎樓，一層
# 二層，走廊
# 一層，平台
# 一層，走廊
# 一層，地下層
# 一層，地下層
# 一層，騎樓
# 二層，走廊
# 二層，陽台
# 一層，騎樓
# 三層，陽台
# 一層，騎樓
# 一層，平台
# 走廊，二層
# 二層，走廊
# 一層，走廊
# 一層，走廊
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，夾層，地下層
# 一層，夾層，地下層
# 一層，走廊
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，騎樓
# 一層，騎樓
# 四層，陽台
# 一層，騎樓
# 四層，陽台
# 二層，陽台
# 一層，騎樓
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 四層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 四層，陽台，平台
# 四層，陽台
# 一層，防空避難室
# 防空避難室，一層
# 一層，二層
# 一層，二層
# 一層，平台
# 一層，平台
# 一層，陽台
# 一層，騎樓
# 二層，陽台
# 三層，陽台
# 一層，陽台，騎樓
# 一層，騎樓
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，二層
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽臺
# 二層，陽台
# 一層，騎樓
# 一層，騎樓
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 一層，騎樓
# 二層，陽台
# 一層，騎樓
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，騎樓
# 四層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 騎樓，一層，平台
# 平台，一層
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，騎樓
# 一層，騎樓
# 三層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，二層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 三層，陽臺
# 三層，陽台
# 三層，陽臺
# 二層，陽台
# 二層，陽台
# 一層，二層
# 一層，平台，騎樓
# 一層，平台，騎樓
# 四層，陽台
# 四層，陽台
# 四層，陽臺
# 三層，陽台
# 二層，陽臺
# 四層，陽臺
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，騎樓
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，騎樓
# 二層，陽台
# 二層，陽台
# 一層，騎樓
# 騎樓，一層
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 二層，陽台
# 四層，陽台
# 陽台，三層
# 一層，二層，騎樓
# 一層，平台，騎樓
# 四層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，夾層
# 一層，夾層
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，平台
# 一層，平台
# 四層，陽台
# 一層，騎樓
# 二層，陽台
# 四層，陽台
# 一層，騎樓，夾層
# 一層，騎樓
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，騎樓
# 一層，騎樓
# 一層，平台，騎樓
# 一層，平台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，騎樓
# 三層，陽台
# 三層，陽台
# 三層，陽臺
# 一層，平台，騎樓
# 四層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 二層，陽臺
# 二層，陽台
# 四層，陽台
# 一層，平台
# 二層，三層
# 二層，三層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 一層，二層
# 一層，平台
# 一層，騎樓
# 二層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，平台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 一層，騎樓
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 二層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台，騎樓
# 二層，陽台
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台
# 一層，平台
# 一層，騎樓
# 四層，陽台
# 三層，陽台
# 一層，騎樓
# 一層，騎樓
# 一層，平台
# 一層，平台，騎樓
# 四層，陽台
# 二層，陽台
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 四層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 一層，騎樓
# 一層，平台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 陽台，二層
# 二層，陽台
# 二層，陽台
# 一層，二層，三層
# 二層，陽台
# 三層，陽台
# 一層，平台
# 陽台，四層
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽臺
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 陽台，二層
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 地下層，一層，平台
# 一層，平台，地下層
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台，地下層
# 一層，平台，騎樓
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 一層，騎樓
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，二層
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 陽台，二層
# 一層，平台
# 一層，平台
# 一層，平台
# 騎樓，一層
# 一層，夾層
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，騎樓
# 一層，平台
# 一層，騎樓
# 一層，平台
# 三層，陽台
# 騎樓，一層，平台
# 一層，平台，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，騎樓
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 一層，騎樓
# 一層，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 一層，騎樓
# 一層，平台
# 四層，陽台
# 四層，陽台
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 四層，陽台
# 一層，地下層
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，騎樓
# 一層，騎樓
# 一層，平台
# 一層，騎樓
# 一層，騎樓
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 一層，騎樓
# 三層，陽台
# 三層，陽臺
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 一層，騎樓
# 一層，平台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 四層，陽臺
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 二層，陽台
# 陽台，四層
# 一層，平台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 一層，地下一層
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，夾層
# 一層，地下層
# 一層，地下層
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，騎樓
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，夾層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，二層，騎樓
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，平台，夾層
# 一層，騎樓
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 陽台，四層
# 一層，平台
# 一層，平台
# 一層，騎樓
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 一層，騎樓
# 一層，夾層
# 一層，夾層
# 四層，陽台
# 一層，平台，騎樓
# 一層，平台，騎樓
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽臺
# 三層，陽台
# 二層，陽臺
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台，騎樓
# 四層，陽台
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽臺
# 一層，騎樓
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，地下層
# 屋頂突出物，一層，二層，三層
# 一層，二層，三層，屋頂突出物
# 一層，二層，三層，屋頂突出物
# 一層，二層，三層，屋頂突出物
# 一層，夾層
# 一層，二層，三層，四層，地下一層
# 一層，二層，三層，四層，地下一層
# 一層，二層
# 一層，二層，三層，屋頂突出物
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，地下一層
# 一層，地下一層
# 一層，地下一層
# 一層，地下一層
# 一層，地下一層
# 一層，地下一層
# 一層，地下一層
# 一層，地下一層
# 一層，地下一層
# 一層，二層
# 一層，二層
# 一層，見其他登記事項
# 一層，二層
# 一層，夾層
# 一層，平台，騎樓
# 一層，騎樓
# 五層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 一層，騎樓
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，騎樓
# 一層，二層
# 一層，平台，騎樓
# 五層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 陽台，二層
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 陽台，二層
# 一層，見其他登記事項
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 平台，一層
# 一層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 陽台，二層
# 三層，陽台
# 平台，一層
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，陽台，平台
# 二層，陽台
# 三層，陽台
# 一層，平台，騎樓
# 一層，騎樓
# 一層，騎樓
# 三層，陽台
# 一層，騎樓
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，二層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，二層
# 一層，二層
# 一層，平台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 陽台，二層
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 陽台，二層
# 三層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 一層，二層，三層
# 一層，二層，三層
# 一層，二層，三層
# 一層，二層，三層
# 一層，二層，三層
# 一層，二層，三層
# 一層，二層，三層，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，見其他登記事項
# 一層，見其他登記事項
# 一層，見其他登記事項
# 一層，見其他登記事項
# 一層，平台
# 一層，夾層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 陽台，三層
# 三層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，儲藏室
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 一層，二層，通道
# 一層，二層，通道
# 一層，二層，通道
# 一層，二層，通道
# 一層，儲藏室
# 一層，儲藏室
# 一層，平台，騎樓
# 一層，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，地下層
# 一層，地下層
# 一層，地下層
# 一層，地下層
# 一層，騎樓
# 一層，平台
# 一層，平台，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 平台，一層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 平台，一層
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 一層，二層，夾層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 平台，騎樓，一層
# 一層，騎樓
# 一層，騎樓
# 騎樓，一層，平台
# 一層，平台
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，騎樓
# 一層，地下層
# 一層，平台
# 一層，二層
# 一層，二層
# 二層，一層
# 一層，二層
# 一層，平台
# 一層，二層，夾層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，平台
# 一層，平台
# 一層，二層，夾層
# 一層，二層，夾層
# 一層，二層，夾層
# 一層，平台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 陽台，二層
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 二層，平台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 一層，騎樓
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 平台，一層
# 一層，平台
# 一層，平台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 一層，騎樓
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 一層，平台
# 五層，陽台，露台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，騎樓
# 一層，騎樓
# 四層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 一層，騎樓
# 四層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 五層，陽台
# 四層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 五層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 陽台，四層
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 平台，一層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 一層，平台
# 五層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 一層，停車場
# 一層，停車場
# 一層，見其他登記事項
# 一層，停車場
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 一層，平台
# 一層，平台
# 三層，平台
# 三層，平台
# 三層，平台
# 三層，平台
# 三層，平台
# 二層，騎樓
# 四層，騎樓
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 一層，騎樓
# 四層，平台
# 四層，平台
# 四層，平台
# 四層，平台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 一層，平台
# 五層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 夾層，一層
# 一層，夾層
# 一層，夾層
# 一層，平台
# 一層，平台
# 平台，一層
# 一層，平台
# 一層，平台
# 二層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 平台，一層
# 一層，平台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，平台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 五層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 陽台，四層
# 四層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 陽台，二層
# 三層，陽台
# 五層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 二層，平台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，平台
# 二層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 陽台，四層
# 一層，平台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 一層，騎樓
# 一層，二層，騎樓，停車場
# 一層，二層，騎樓
# 一層，二層，騎樓，停車場
# 一層，二層，夾層
# 一層，二層，夾層
# 一層，二層，夾層
# 一層，二層，夾層
# 一層，二層，夾層
# 一層，二層，夾層
# 一層，二層，夾層
# 三層，陽台
# 一層，二層，夾層
# 三層，陽台
# 陽台，四層
# 一層，平台
# 四層，陽台
# 陽台，四層
# 一層，平台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台，騎樓
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 平台，騎樓，一層
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 一層，車庫
# 一層，車庫
# 一層，地下層
# 一層，夾層
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 陽台，三層
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 陽台，三層
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 一層，平台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 陽台，三層
# 一層，平台
# 一層，平台
# 三層，陽台
# 一層，騎樓
# 一層，平台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 三層，陽台
# 陽台，三層
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 五層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 陽台，四層
# 一層，平台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 一層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台，騎樓
# 三層，陽台
# 二層，陽台
# 陽台，四層
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 陽台，四層
# 四層，陽台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 一層，平台，騎樓
# 四層，陽台
# 陽台，二層
# 四層，陽台
# 五層，陽台
# 陽台，五層
# 一層，平台
# 一層，平台
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 三層，陽台
# 平台，一層
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 三層，陽台
# 陽台，三層
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 一層，騎樓
# 四層，陽台
# 五層，陽台
# 陽台，五層
# 陽台，四層
# 五層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 一層，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 一層，騎樓
# 二層，陽台
# 五層，陽台
# 一層，二層
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 平台，一層
# 一層，平台
# 一層，平台，騎樓
# 一層，平台
# 一層，二層，陽台，平台
# 一層，平台
# 一層，平台
# 一層，二層，陽台，平台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 陽台，三層
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 平台，一層
# 一層，平台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 陽台，三層
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 一層，地下層
# 二層，陽台
# 一層，平台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 陽台，四層
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 一層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，二層
# 一層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 三層，陽台
# 陽台，三層
# 四層，陽台
# 四層，陽台
# 平台，一層
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 一層，二層
# 一層，二層
# 一層，二層
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 一層，騎樓
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 四層，平台
# 平台，一層
# 一層，平台
# 一層，平台
# 三層，平台
# 四層，平台
# 三層，平台
# 二層，平台
# 三層，平台
# 一層，平台
# 二層，陽台
# 三層，平台
# 四層，平台
# 二層，平台
# 一層，二層，三層，四層，五層，騎樓
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 五層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，停車場
# 二層，陽台
# 三層，陽台
# 一層，二層
# 一層，二層
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 陽台，二層
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 四層，平台
# 四層，陽台
# 五層，陽台
# 平台，地下二層
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 陽台，三層
# 一層，平台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 陽台，四層
# 一層，夾層
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 平台，一層
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 四層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 一層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 一層，平台
# 一層，平台
# 陽台，一層
# 四層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 一層，二層
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 陽台，四層
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 一層，二層
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 一層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 陽台，四層
# 四層，陽台
# 一層，二層，陽台，平台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 一層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，平台
# 四層，陽台
# 一層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 陽台，一層
# 四層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 四層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 五層，平台
# 一層，平台
# 五層，陽台
# 一層，平台
# 一層，二層
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 陽台，五層
# 五層，陽台
# 三層，陽台
# 陽台，三層
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 陽台，四層
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 陽台，五層
# 四層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 一層，二層
# 一層，二層
# 一層，二層，三層
# 一層，二層
# 四層，陽台
# 一層，夾層
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，二層，三層
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 一層，花台
# 一層，花台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 陽台，二層
# 二層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 陽台，二層
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 陽台，二層
# 四層，陽台
# 陽台，四層
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 五層，陽台
# 三層，陽台
# 一層，平台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 陽台，五層
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 一層，二層
# 三層，陽台
# 一層，平台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 騎樓，一層
# 一層，平台
# 一層，平台
# 五層，陽台
# 一層，平台
# 一層，平台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，停車場
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 陽台，二層
# 三層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 平台，一層
# 一層，平台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，二層，陽台，平台
# 三層，平台
# 三層，平台
# 四層，平台
# 五層，陽台
# 一層，平台，騎樓
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 陽台，五層
# 一層，平台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 五層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 一層，騎樓
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 一層，騎樓
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 陽台，三層
# 四層，陽台
# 一層，騎樓
# 四層，陽台
# 三層，陽台
# 陽台，三層
# 三層，陽台
# 一層，騎樓
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 陽台，二層
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，夾層
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 五層，陽台
# 一層，平台
# 四層，陽台
# 陽台，三層
# 二層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，平台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 一層，平台，騎樓
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 一層，騎樓
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 陽台，五層
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 一層，陽台
# 一層，陽台
# 一層，平台
# 二層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 陽台，三層
# 三層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 陽台，二層
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 五層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 陽台，四層
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 陽台，二層
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 陽台，二層
# 二層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 陽台，五層
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 陽台，四層
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 一層，騎樓
# 一層，騎樓
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 一層，騎樓
# 五層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 一層，騎樓
# 二層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 陽台，五層
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 平台，一層
# 三層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 一層，騎樓
# 陽台，四層
# 五層，陽台
# 五層，陽台
# 一層，平台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 一層，平台
# 三層，陽台
# 五層，陽台
# 一層，平台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 陽台，四層
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 陽台，四層
# 四層，陽台
# 陽台，三層
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 五層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 一層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 一層，平台
# 一層，騎樓
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 一層，二層
# 四層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 一層，平台，地下層
# 二層，陽台
# 一層，平台，地下層
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 一層，陽台
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 一層，平台
# 五層，陽台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 陽台，二層
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 五層，陽台
# 一層，騎樓
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 陽台，二層
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 陽台，三層
# 一層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 五層，陽台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 五層，陽台
# 一層，平台
# 一層，走廊
# 五層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 五層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 一層，騎樓
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 一層，二層
# 一層，二層
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 二層，平台
# 一層，騎樓
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 一層，二層，三層，四層
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 一層，騎樓
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 一層，騎樓
# 一層，騎樓
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 一層，平台
# 一層，陽台
# 三層，陽台
# 三層，陽台
# 平台，一層
# 一層，平台
# 一層，平台
# 三層，陽台
# 四層，五層，陽台
# 二層，陽台
# 四層，五層
# 四層，五層
# 四層，五層
# 四層，五層，陽台
# 四層，五層，陽台
# 四層，五層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 平台，一層
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 陽台，四層
# 五層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 一層，平台
# 平台，一層
# 一層，平台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 陽台，四層
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 陽台，三層
# 一層，平台
# 二層，陽台
# 五層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 一層，陽台
# 三層，陽台
# 一層，門廳
# 五層，陽台
# 三層，陽臺
# 二層，陽台
# 一層，平台
# 四層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，地下一層
# 一層，平台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 二層，陽台
# 一層，二層，陽臺，平台
# 一層，二層，騎樓
# 一層，二層，騎樓
# 一層，二層，騎樓
# 一層，二層，騎樓
# 一層，二層，騎樓
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 陽台，三層
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 五層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 一層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 平台，一層
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 一層，二層，陽台，平台，騎樓
# 四層，陽台
# 一層，二層，陽台，平台，騎樓
# 二層，陽台
# 四層，陽台
# 二層，騎樓
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 陽台，二層
# 一層，二層
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 平台，一層
# 一層，平台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 陽台，四層
# 三層，陽台
# 一層，平台，騎樓
# 四層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台，騎樓
# 四層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 五層，陽台
# 三層，陽台
# 陽台，四層
# 四層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 陽台，二層
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 二層，平台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 陽台，三層
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 一層，平台
# 一層，平台
# 五層，陽台
# 陽台，五層
# 五層，陽台
# 二層，平台
# 二層，平台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 陽台，三層
# 五層，陽台
# 三層，陽台
# 一層，二層
# 一層，二層
# 一層，二層
# 二層，陽台
# 陽台，三層
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 一層，二層
# 一層，二層
# 一層，二層
# 四層，五層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 一層，騎樓
# 一層，二層，陽台，平台，騎樓
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 陽台，三層
# 陽台，三層
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 一層，騎樓
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 四層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 陽台，四層
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 一層，二層，陽台，平台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 平台，一層
# 一層，平台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 陽台，四層
# 五層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 三層，夾層
# 二層，一層
# 二層，三層
# 二層，三層
# 四層，五層
# 四層，五層
# 四層，五層，夾層
# 四層，五層
# 四層，五層
# 三層，四層，五層
# 四層，五層，屋頂突出物
# 三層，夾層
# 三層，夾層
# 一層，二層
# 一層，二層
# 一層，平台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，騎樓
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 陽台，三層
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，騎樓
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台，停車場
# 停車場，一層
# 一層，停車場
# 一層，停車場
# 一層，騎樓
# 陽台，四層
# 二層，陽台
# 四層，陽台
# 一層，停車場
# 一層，平台
# 一層，平台
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 三層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 四層，陽臺
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，二層，三層
# 一層，二層，三層
# 一層，二層，三層
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 陽台，三層
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 一層，停車場
# 一層，停車場
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 停車場，一層
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 三層，陽台
# 陽台，二層
# 三層，陽台
# 一層，平台
# 三層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 一層，騎樓，停車場
# 一層，平台
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，二層，夾層
# 一層，平台
# 一層，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，停車場
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，平台
# 一層，騎樓
# 一層，陽台
# 一層，二層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，停車場
# 一層，平台
# 一層，騎樓
# 一層，平台
# 一層，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 平台，一層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，二層，陽台，平台
# 二層，陽台，一層，平台
# 一層，二層，陽台，平台
# 一層，平台
# 一層，平台
# 一層，二層，陽台，平台
# 一層，平台
# 一層，平台
# 一層，夾層
# 一層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，二層
# 一層，二層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，陽台
# 一層，二層，陽台，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 平台，一層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，二層
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，二層，騎樓
# 一層，地下層
# 平台，一層
# 一層，停車場，儲藏室
# 一層，通道
# 一層，通道
# 一層，通道
# 一層，平台
# 一層，平台
# 平台，一層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，地下層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，平台
# 一層，平台，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，二層
# 一層，二層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，陽台
# 一層，平台
# 一層，平台
# 一層，平台，地下層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 平台，一層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，車庫
# 一層，車庫
# 一層，平台
# 一層，平台
# 一層，騎樓，夾層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，陽台
# 一層，陽臺
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台，騎樓
# 一層，騎樓
# 一層，平台，地下層
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台，地下層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台，騎樓
# 一層，騎樓
# 一層，平台
# 一層，平台，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，停車場
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 平台，一層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，二層，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，平台
# 一層，平台
# 一層，二層
# 一層，二層
# 一層，二層，三層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台，騎樓
# 一層，平台
# 一層，陽台
# 一層，夾層
# 一層，平台，騎樓
# 一層，平台
# 一層，平台
# 一層，二層，陽台，平台，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，通道
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，騎樓
# 二層，走廊
# 二層，走廊
# 一層，走廊
# 一層，走廊
# 一層，平台
# 走廊，一層
# 二層，走廊
# 一層，停車場
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，夾層
# 一層，夾層
# 一層，二層，屋頂突出物，見其他登記事項
# 一層，二層，屋頂突出物，見其他登記事項
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 騎樓，一層
# 一層，地下一層
# 一層，地下一層
# 一層，騎樓
# 一層，二層，三層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 二層，一層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層，三層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層，地下層
# 一層，二層，地下層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，地下一層，地下二層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 二層，地下一層，一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 二層，地下一層，一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 二層，一層，地下一層
# 一層，二層，地下層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，三層，四層，電梯樓梯間，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 一層，騎樓
# 一層，見其他登記事項
# 一層，見其他登記事項
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，地下一層
# 一層，地下一層
# 一層，地下一層
# 一層，地下層
# 一層，地下層
# 一層，地下一層
# 一層，二層
# 二層，一層
# 一層，地下層
# 一層，停車場
# 一層，騎樓
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層，夾層
# 二層，夾層，一層
# 一層，夾層
# 一層，夾層
# 一層，二層
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 二層，陽台
# 五層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 陽台，四層
# 四層，陽台
# 一層，平台
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 平台，一層
# 一層，平台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 陽台，四層
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台，騎樓
# 四層，陽台
# 陽台，三層
# 三層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 一層，平台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 一層，平台
# 一層，騎樓
# 二層，陽台
# 五層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 陽台，三層
# 一層，騎樓
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 陽台，三層
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 陽台，四層
# 五層，陽台
# 陽台，五層
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 一層，夾層
# 一層，夾層
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 平台，騎樓，一層
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 騎樓，一層，平台
# 四層，陽台
# 陽台，四層
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 陽台，三層
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 陽台，二層
# 三層，陽台
# 陽台，三層
# 二層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 五層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 一層，騎樓
# 一層，二層
# 一層，二層
# 四層，五層
# 四層，陽台
# 一層，騎樓
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 平台，一層
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 陽台，二層
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 二層，三層
# 一層，騎樓
# 一層，騎樓
# 一層，二層，三層
# 四層，五層，夾層
# 一層，平台
# 四層，五層，夾層
# 一層，二層，三層
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 一層，騎樓
# 一層，騎樓
# 一層，二層，騎樓
# 三層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 四層，平台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 陽台，三層
# 一層，平台
# 四層，陽台
# 陽台，二層
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 陽台，四層
# 一層，騎樓
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，騎樓
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台，騎樓
# 一層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 一層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 一層，陽台，騎樓
# 一層，騎樓
# 三層，陽台
# 一層，騎樓
# 四層，陽台
# 一層，平台
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 五層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 四層，陽台
# 一層，騎樓，平台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 一層，平台，騎樓
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台，騎樓
# 四層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台，騎樓
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 平台，一層
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 陽台，三層
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 一層，騎樓
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，陽台
# 一層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 一層，騎樓
# 二層，陽台
# 四層，陽台
# 陽台，二層
# 三層，陽台
# 陽台，三層
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 陽台，四層
# 三層，陽台
# 五層，陽台
# 陽台，五層
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，騎樓
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 陽台，二層
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 陽台，三層
# 三層，陽台
# 四層，陽台
# 陽台，三層
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 陽台，三層
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，騎樓
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 一層，二層
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 騎樓，一層，二層
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 五層，陽台
# 五層，陽台
# 一層，騎樓
# 一層，騎樓
# 一層，二層，騎樓
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 一層，平台
# 一層，騎樓
# 五層，陽台
# 一層，平台
# 四層，陽台
# 一層，騎樓
# 一層，騎樓
# 二層，陽台
# 一層，騎樓
# 一層，騎樓
# 二層，陽台
# 二層，陽台
# 陽台，四層
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，夾層
# 一層，夾層
# 一層，騎樓
# 一層，陽台
# 一層，陽台
# 一層，平台
# 一層，平台
# 平台，一層
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 地下層，一層
# 一層，見使用執照
# 一層，見使用執照
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 一層，平台
# 陽台，四層
# 四層，陽台
# 一層，平台
# 一層，二層
# 一層，見其他登記事項
# 一層，見其他登記事項
# 一層，騎樓
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 陽台，三層
# 三層，陽台
# 二層，陽台
# 五層，陽台
# 一層，平台，地下層
# 一層，平台
# 一層，騎樓
# 一層，騎樓
# 三層，陽台
# 三層，陽台
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，二層，騎樓
# 一層，二層
# 三層，陽台
# 一層，地下層
# 二層，陽台
# 四層，陽台
# 一層，騎樓
# 一層，騎樓
# 三層，陽台
# 三層，陽台
# 一層，平台，騎樓
# 一層，騎樓
# 三層，陽台
# 三層，陽台
# 一層，二層
# 一層，見其他登記事項
# 四層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 陽台，二層
# 三層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 一層，騎樓
# 陽台，二層
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 一層，平台
# 一層，地下層
# 一層，騎樓
# 一層，騎樓
# 一層，儲藏室
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 十三層，見其他登記事項
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 平台，一層
# 一層，平台
# 三層，陽台
# 陽台，三層
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 陽台，四層
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 陽台，四層
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 一層，平台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，平台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 平台，三層
# 三層，平台
# 二層，陽台
# 二層，陽台
# 四層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，二層，三層
# 一層，二層，三層
# 四層，陽台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 陽台，三層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台，騎樓
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 一層，平台，騎樓
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 陽台，四層
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台，騎樓
# 四層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，見其他登記事項
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 陽台，三層
# 五層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 五層，陽台
# 一層，二層
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 騎樓，一層
# 一層，平台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 平台，一層
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 二層，平台
# 一層，平台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 二層，平台
# 二層，平台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，平台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 四層，平台
# 四層，陽台
# 陽台，三層
# 一層，平台
# 三層，陽台
# 三層，陽台
# 一層，陽台
# 一層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 一層，騎樓
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，地下層
# 一層，騎樓
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，二層，騎樓
# 一層，騎樓
# 一層，地下層
# 一層，地下層
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，騎樓
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 陽台，五層
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，騎樓
# 五層，陽台
# 四層，陽台
# 一層，平台
# 一層，騎樓
# 三層，陽台
# 四層，陽台
# 陽台，四層
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 三層，陽台
# 一層，騎樓
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 二層，平台
# 五層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 一層，二層，夾層
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 一層，騎樓
# 二層，三層，一層，屋頂突出物
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 三層，陽台
# 一層，見其他登記事項
# 一層，二層
# 一層，夾層
# 一層，夾層
# 一層，見其他登記事項
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層，三層，四層，屋頂突出物，地下一層
# 二層，陽台
# 一層，二層，夾層，地下層
# 一層，二層，夾層，地下層
# 一層，二層
# 一層，二層
# 一層，二層，三層，四層
# 一層，停車場
# 四層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層，地下一層
# 一層，二層，地下一層
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，二層，三層，屋頂突出物
# 一層，二層
# 一層，平台
# 一層，平台
# 一層，二層
# 一層，騎樓
# 一層，騎樓，夾層
# 一層，騎樓，夾層
# 二層，陽台
# 一層，平台，騎樓
# 四層，陽台
# 陽台，二層
# 四層，陽台
# 陽台，四層
# 一層，停車場
# 一層，停車場
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 陽台，四層
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 陽台，三層
# 陽台，四層
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 陽台，三層
# 四層，陽台
# 四層，陽台
# 平台，一層
# 四層，陽台
# 一層，停車場
# 五層，陽台
# 三層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 陽台，三層
# 三層，陽台
# 陽台，三層
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，停車場
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 陽台，三層
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 陽台，三層
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 一層，停車場
# 一層，二層
# 一層，二層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，平台，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，電梯樓梯間
# 一層，電梯樓梯間
# 一層，平台
# 一層，騎樓
# 一層，平台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，二層
# 二層，陽台
# 一層，停車場
# 停車場，一層
# 一層，停車場
# 平台，一層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 平台，一層
# 一層，平台
# 一層，停車場
# 一層，停車場
# 一層，平台
# 一層，平台
# 一層，平台，停車場
# 二層，騎樓
# 一層，二層，騎樓
# 一層，二層，停車場，夾層
# 三層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 一層，二層，夾層
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 一層，陽台
# 一層，陽台
# 陽台，一層
# 一層，平台
# 四層，陽台
# 一層，騎樓
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 一層，停車場
# 二層，陽台
# 二層，陽台
# 一層，夾層
# 三層，走廊
# 四層，走廊
# 四層，走廊
# 三層，走廊
# 三層，走廊
# 三層，走廊
# 四層，走廊
# 二層，走廊
# 四層，走廊
# 四層，走廊
# 四層，走廊
# 二層，走廊
# 四層，走廊
# 四層，走廊
# 四層，陽台
# 三層，走廊
# 四層，走廊
# 四層，走廊
# 四層，走廊
# 四層，走廊
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 一層，停車場
# 一層，停車場
# 二層，陽台
# 三層，陽台
# 走廊，四層
# 四層，走廊
# 二層，走廊
# 三層，走廊
# 二層，走廊
# 三層，走廊
# 四層，走廊
# 二層，走廊
# 三層，走廊
# 走廊，三層
# 二層，走廊
# 四層，走廊
# 四層，走廊
# 走廊，四層
# 三層，走廊
# 三層，走廊
# 四層，走廊
# 二層，走廊
# 二層，走廊
# 一層，停車場
# 一層，平台
# 一層，平台
# 二層，陽台
# 平台，一層
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 一層，走廊
# 四層，陽台
# 四層，走廊
# 五層，陽台
# 四層，陽台
# 三層，走廊
# 三層，陽台
# 四層，陽台
# 二層，走廊
# 一層，二層
# 一層，平台
# 見其他登記事項，一層
# 二層，走廊
# 四層，走廊
# 二層，走廊
# 四層，走廊
# 四層，走廊
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 四層，屋頂突出物
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，走廊
# 一層，平台
# 二層，陽台
# 二層，陽台
# 四層，走廊
# 四層，走廊
# 二層，走廊
# 二層，陽台
# 二層，陽台
# 一層，見其他登記事項
# 一層，夾層
# 二層，走廊
# 四層，走廊
# 四層，走廊
# 三層，走廊
# 三層，走廊
# 四層，走廊
# 四層，走廊
# 四層，走廊
# 三層，走廊
# 三層，走廊
# 一層，走廊
# 二層，走廊
# 三層，走廊
# 四層，走廊
# 一層，走廊
# 一層，走廊
# 一層，走廊
# 一層，走廊
# 一層，走廊
# 一層，二層
# 一層，二層
# 一層，二層
# 二十一層，二十層
# 一層，夾層
# 一層，二層
# 一層，見其他登記事項
# 二層，走廊
# 五層，走廊
# 二層，走廊
# 一層，走廊
# 一層，二層，三層，四層
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 二層，走廊
# 一層，走廊
# 一層，走廊
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 四層，走廊
# 四層，走廊
# 四層，走廊
# 一層，走廊
# 一層，走廊
# 一層，騎樓
# 一層，走廊
# 三層，走廊
# 二層，走廊
# 三層，陽台
# 一層，走廊
# 三層，走廊
# 三層，走廊
# 一層，走廊
# 一層，走廊
# 三層，走廊
# 一層，二層，騎樓
# 一層，二層，騎樓
# 三層，走廊
# 三層，走廊
# 三層，走廊
# 三層，走廊
# 三層，走廊
# 三層，走廊
# 三層，走廊
# 走廊，地下層
# 二層，走廊
# 三層，走廊
# 三層，走廊
# 一層，走廊
# 一層，走廊
# 四層，走廊
# 一層，走廊
# 三層，走廊
# 三層，陽台
# 走廊，地下層
# 四層，走廊
# 四層，走廊
# 四層，走廊
# 四層，走廊
# 一層，走廊
# 一層，走廊
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 平台，一層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，二層，三層，地下層
# 一層，走廊
# 一層，走廊
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，走廊
# 二層，走廊
# 一層，走廊
# 二層，走廊
# 三層，走廊
# 二層，走廊
# 二層，走廊
# 二層，走廊
# 一層，騎樓，走廊
# 一層，走廊
# 二層，走廊
# 二層，走廊
# 一層，走廊
# 二層，走廊
# 一層，騎樓，走廊
# 一層，走廊
# 一層，騎樓，走廊
# 一層，騎樓，走廊
# 一層，走廊
# 一層，走廊
# 四層，走廊
# 四層，走廊
# 四層，走廊
# 四層，走廊
# 四層，走廊
# 二層，走廊
# 三層，走廊
# 四層，走廊
# 二層，走廊
# 二層，走廊
# 四層，走廊
# 三層，走廊
# 四層，走廊
# 走廊，三層
# 走廊，一層
# 走廊，一層
# 二層，走廊
# 二層，走廊
# 三層，走廊
# 四層，走廊
# 四層，走廊
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 陽台，四層
# 一層，停車場
# 一層，騎樓，走廊
# 二層，走廊
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 一層，二層
# 三層，走廊
# 四層，走廊
# 四層，走廊
# 四層，走廊
# 二層，走廊
# 三層，走廊
# 二層，走廊
# 二層，走廊
# 一層，走廊
# 三層，走廊
# 走廊，四層
# 四層，走廊
# 二層，走廊
# 走廊，三層
# 三層，走廊
# 二層，走廊
# 二層，走廊
# 三層，走廊
# 一層，走廊
# 三層，走廊
# 三層，走廊
# 二層，走廊
# 四層，走廊
# 四層，走廊
# 四層，走廊
# 一層，走廊
# 四層，走廊
# 二層，走廊
# 四層，走廊
# 四層，走廊
# 四層，走廊
# 四層，走廊
# 四層，走廊
# 二層，走廊
# 四層，走廊
# 一層，走廊
# 一層，走廊
# 一層，儲藏室
# 三層，走廊
# 三層，走廊
# 三層，走廊
# 三層，走廊
# 四層，走廊
# 二層，走廊
# 二層，走廊
# 三層，走廊
# 四層，走廊
# 二層，走廊
# 三層，走廊
# 一層，走廊
# 二層，走廊
# 一層，走廊
# 一層，走廊
# 二層，走廊
# 三層，走廊
# 三層，走廊
# 一層，二層，夾層
# 三層，四層，五層，電梯樓梯間
# 一層，二層，夾層
# 一層，二層，夾層
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 一層，二層，夾層
# 四層，五層，電梯樓梯間，三層
# 一層，二層，夾層
# 一層，二層，夾層
# 電梯樓梯間，三層，四層，五層
# 一層，二層，夾層
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 夾層，一層，二層
# 四層，五層，三層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 一層，二層，夾層
# 一層，二層，夾層
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 一層，二層，夾層
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 一層，二層，夾層
# 三層，四層，五層，電梯樓梯間
# 一層，二層，夾層
# 三層，四層，五層，電梯樓梯間
# 一層，二層，夾層
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 一層，二層，夾層
# 一層，二層，夾層
# 電梯樓梯間，三層，四層，五層
# 一層，二層，夾層
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 一層，二層，夾層
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 一層，二層，夾層
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 一層，二層，夾層
# 一層，二層，夾層
# 三層，四層，五層，電梯樓梯間
# 三層，四層，五層，電梯樓梯間
# 一層，二層，夾層
# 三層，四層，五層，電梯樓梯間
# 一層，二層，夾層
# 一層，二層
# 一層，走廊
# 一層，走廊
# 四層，走廊
# 四層，走廊
# 一層，二層，三層，走廊
# 一層，二層，三層，騎樓
# 一層，二層
# 一層，二層
# 一層，二層
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 一層，陽台，平台
# 平台，地下層
# 三層，陽台
# 四層，走廊
# 二層，走廊
# 一層，走廊
# 二層，走廊
# 一層，走廊
# 三層，走廊
# 二層，平台
# 三層，陽台
# 五層，陽台
# 四層，走廊
# 五層，陽台
# 陽台，五層
# 二層，陽台
# 二層，走廊
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 一層，走廊
# 一層，騎樓
# 一層，走廊
# 一層，走廊，地下層
# 二層，陽台
# 三層，陽台
# 陽台，二層
# 五層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，走廊
# 三層，走廊
# 一層，平台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 四層，走廊
# 一層，二層
# 一層，見其他登記事項
# 三層，走廊
# 四層，走廊
# 四層，走廊
# 四層，走廊
# 四層，走廊
# 一層，走廊
# 一層，平台
# 一層，走廊
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 一層，走廊
# 二層，走廊
# 一層，二層，夾層
# 一層，二層，三層
# 一層，二層
# 一層，平台
# 一層，見其他登記事項
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，走廊
# 一層，走廊
# 一層，平台
# 二層，騎樓
# 三層，走廊
# 四層，陽台
# 二層，走廊
# 一層，二層，三層
# 一層，見其他登記事項
# 一層，見其他登記事項
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，走廊
# 五層，走廊
# 三層，走廊
# 走廊，三層
# 四層，走廊
# 二層，走廊
# 三層，走廊
# 三層，走廊
# 三層，走廊
# 三層，走廊
# 三層，走廊
# 三層，走廊
# 三層，走廊
# 三層，走廊
# 三層，走廊
# 一層，走廊
# 二層，走廊
# 二層，走廊
# 三層，走廊
# 一層，走廊
# 一層，走廊
# 三層，陽台
# 二層，走廊
# 二層，走廊
# 四層，陽台
# 四層，陽台
# 一層，走廊
# 一層，走廊
# 一層，走廊
# 一層，走廊
# 一層，走廊
# 二層，走廊
# 四層，陽台
# 四層，陽台
# 三層，走廊
# 四層，陽台
# 二層，陽台
# 二層，走廊
# 三層，走廊
# 二層，走廊
# 二層，走廊
# 一層，走廊
# 二層，走廊
# 三層，走廊
# 三層，走廊
# 三層，走廊
# 一層，走廊
# 三層，走廊
# 三層，走廊
# 一層，停車場
# 一層，停車場
# 四層，陽台
# 陽台，四層
# 五層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 一層，停車場
# 三層，走廊
# 三層，走廊
# 三層，走廊
# 四層，走廊
# 一層，走廊
# 四層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 陽台，二層
# 四層，陽台
# 陽台，三層
# 四層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 三層，走廊
# 三層，陽台
# 三層，陽台
# 三層，走廊
# 三層，走廊
# 三層，走廊
# 四層，走廊
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 一層，走廊
# 三層，陽台
# 三層，陽台
# 二層，走廊
# 四層，走廊
# 一層，走廊
# 二層，走廊
# 一層，走廊
# 四層，陽台
# 三層，走廊
# 一層，走廊
# 三層，走廊
# 二層，走廊
# 四層，走廊
# 二層，走廊
# 四層，走廊
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 二層，走廊
# 四層，走廊
# 四層，走廊
# 三層，陽台
# ...
# 陽台，三層
# 四層，陽台
# 三層，陽台
# 陽台，三層
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 一層，二層
# 一層，二層，地下一層
# 一層，停車場
# 四層，五層，夾層
# 四層，五層，夾層
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，平台
# 一層，夾層
# 一層，夾層
# 夾層，一層
# 一層，夾層
# 一層，夾層
# 夾層，一層
# 夾層，一層
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 一層，二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 七層，陽台
# 一層，平台
# 二層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 陽台，四層
# 四層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 五層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 陽台，四層
# 一層，平台
# 二層，陽台
# 五層，陽台
# 陽台，四層
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，騎樓，停車場
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 陽台，三層
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 五層，陽台
# 一層，平台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 二層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台，停車場
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 陽台，五層
# 一層，騎樓
# 陽台，三層
# 一層，騎樓
# 一層，騎樓
# 二層，陽台
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 三層，陽台
# 四層，陽台
# 一層，陽台
# 三層，陽台
# 三層，陽台
# 陽台，四層
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 陽台，三層
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 陽台，四層
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 陽台，二層
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台，停車場
# 五層，陽台
# 陽台，四層
# 一層，平台，停車場
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 一層，騎樓
# 一層，騎樓
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 陽台，三層
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 陽台，五層
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 一層，騎樓，停車場
# 一層，騎樓，停車場
# 一層，騎樓
# 一層，騎樓
# 一層，停車場
# 一層，地下一層
# 一層，騎樓，停車場
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，夾層
# 一層，夾層
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 一層，停車場
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 二層，陽台
# 一層，騎樓
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 陽台，五層
# 陽台，五層
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 騎樓，一層
# 一層，騎樓
# 一層，騎樓
# 二層，陽台
# 一層，騎樓
# 一層，騎樓
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 騎樓，一層
# 一層，騎樓
# 一層，平台，停車場
# 一層，平台
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，平台
# 一層，平台
# 一層，平台，騎樓
# 一層，騎樓，停車場
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，騎樓
# 一層，平台
# 平台，一層
# 一層，平台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 陽台，三層
# 一層，平台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 陽台，二層
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，停車場
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 騎樓，一層，平台
# 二層，陽台
# 三層，陽台
# 陽台，三層
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 陽台，四層
# 四層，陽台
# 三層，陽台
# 陽台，四層
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 陽台，三層
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，騎樓，停車場，夾層
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 陽台，二層
# 一層，平台
# 一層，平台，騎樓
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，停車場
# 三層，陽台
# 二層，陽台
# 一層，地下一層
# 一層，地下一層
# 地下層，一層
# 一層，地下層
# 一層，地下層
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 一層，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 一層，二層，三層，四層，見其他登記事項
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 一層，停車場
# 一層，停車場
# 一層，平台
# 一層，平台
# 一層，停車場
# 一層，平台
# 一層，停車場
# 一層，停車場
# 四層，陽台
# 四層，陽台
# 陽台，四層
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 陽台，三層
# 四層，陽台
# 一層，停車場
# 一層，停車場
# 三層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 陽台，三層
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 陽台，三層
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 陽台，三層
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 陽台，四層
# 陽台，四層
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 陽台，五層
# 三層，陽台
# 陽台，四層
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 陽台，二層
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 陽台，五層
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 陽台，三層
# 四層，陽台
# 五層，陽台
# 一層，停車場
# 三層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 陽台，三層
# 四層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 一層，平台
# 陽台，二層
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，二層
# 一層，停車場
# 一層，停車場
# 夾層，一層
# 一層，二層，地下層
# 一層，停車場
# 一層，停車場
# 停車場，一層
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 一層，平台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，騎樓，停車場
# 一層，停車場
# 陽台，五層
# 一層，停車場
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，騎樓，停車場
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，二層，三層
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 平台，一層
# 四層，陽台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 一層，平台，騎樓
# 一層，平台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台，騎樓
# 平台，騎樓，一層
# 四層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 陽台，四層
# 四層，陽台
# 一層，停車場
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，停車場
# 一層，停車場
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，騎樓，停車場
# 二層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 陽台，二層
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 陽台，二層
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台，騎樓
# 四層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 陽台，四層
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台，騎樓
# 四層，陽台
# 陽台，三層
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 一層，騎樓
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 陽台，三層
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 一層，陽台
# 二層，陽台
# 一層，陽台
# 四層，陽台
# 四層，陽台
# 一層，陽台
# 四層，陽台
# 一層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 陽台，二層
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 陽台，一層
# 一層，陽台
# 一層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 陽台，三層
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 陽台，四層
# 四層，陽台
# 二層，陽台
# 一層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，陽台
# 三層，陽台
# 一層，陽台
# 一層，陽台
# 四層，陽台
# 一層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 陽台，三層
# 四層，陽台
# 一層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 陽台，二層
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，陽台
# 陽台，二層
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，陽台
# 四層，陽台
# 一層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，陽台
# 二層，陽台
# 一層，陽台
# 一層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 陽台，四層
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，騎樓
# 四層，陽台
# 四層，陽台
# 一層，騎樓
# 一層，騎樓
# 一層，平台，騎樓
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台，騎樓
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 一層，二層，夾層
# 四層，陽台
# 二層，陽台
# 一層，二層，夾層
# 一層，二層，夾層
# 一層，二層，夾層
# 五層，陽台
# 五層，陽台
# 陽台，五層
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 夾層，一層，二層
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，停車場
# 一層，停車場
# 二層，陽台
# 陽台，三層
# 一層，平台，騎樓
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 陽台，四層
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 五層，陽台
# 陽台，五層
# 陽台，五層
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 一層，夾層
# 一層，夾層
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 陽台，二層
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 陽台，三層
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 一層，夾層
# 一層，平台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 四層，陽台
# 一層，二層，夾層
# 一層，二層，夾層
# 一層，二層，夾層
# 一層，二層，夾層
# 一層，二層，夾層
# 一層，二層，夾層
# 一層，停車場
# 一層，平台，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 陽台，四層
# 一層，平台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 陽台，二層
# 四層，陽台
# 一層，騎樓
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 騎樓，一層，平台
# 平台，騎樓，一層
# 四層，陽台
# 一層，平台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 陽台，二層
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 一層，停車場
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 陽台，三層
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 三層，平台
# 一層，平台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 一層，夾層
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 一層，騎樓
# 一層，夾層
# 一層，夾層
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 一層，陽台
# 四層，陽台
# 四層，陽台
# 一層，停車場
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，停車場
# 一層，停車場
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，騎樓
# 一層，平台
# 一層，平台
# 一層，停車場
# 一層，停車場
# 二層，陽台，平台，一層
# 一層，二層，陽台，平台
# 一層，停車場
# 一層，平台
# 一層，平台，騎樓
# 四層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 一層，二層
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台，停車場
# 陽台，二層
# 三層，陽台
# 二層，陽台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，騎樓
# 四層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 平台，一層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 五層，陽台
# 一層，平台，騎樓
# 騎樓，一層，平台
# 五層，陽台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 一層，平台，騎樓
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 一層，平台，騎樓
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 陽台，三層
# 四層，陽台
# 二層，陽台
# 騎樓，一層，平台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台，騎樓
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 陽台，四層
# 四層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 陽台，三層
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 陽台，四層
# 一層，平台
# 三層，陽台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 一層，平台，騎樓，停車場
# 一層，平台，騎樓，停車場
# 停車場，一層
# 一層，停車場
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 五層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 停車場，一層，平台，騎樓
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 五層，陽台
# 二層，陽台
# 一層，平台，騎樓，停車場
# 四層，陽台
# 一層，停車場
# 四層，陽台
# 四層，陽台
# 一層，平台，騎樓，停車場
# 一層，騎樓，停車場
# 一層，騎樓
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 陽台，四層
# 二層，陽台
# 平台，一層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 平台，一層
# 一層，平台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 陽台，四層
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 陽台，三層
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 一層，二層
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 五層，陽台
# 三層，陽台
# 陽台，四層
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 五層，陽台
# 五層，陽台
# 五層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 五層，陽台
# 五層，陽台
# 三層，陽台
# 一層，停車場
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 一層，平台，騎樓
# 一層，平台，騎樓
# 二層，陽台
# 二層，陽台
# 二層，陽台
# 一層，平台，騎樓
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 一層，平台，騎樓
# 二層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 一層，平台
# 四層，陽台
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 停車場，一層
# 一層，停車場
# 二層，陽台
# 一層，停車場
# 一層，停車場
# 一層，停車場
# 五層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，騎樓
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 三層，陽台
# 一層，二層
# 一層，二層
# 四層，陽台
# 一層，二層
# 三層，陽台
# 三層，陽台
# 一層，平台，停車場
# 五層，陽台
# 一層，平台，停車場
# 一層，平台
# 一層，平台
# 二層，陽台
# 四層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 陽台，三層
# 一層，停車場
# 一層，停車場
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 三層，陽台
# 二層，陽台
# 四層，陽台
# 三層，陽台
# 一層，停車場
# 一層，停車場，騎樓
# 一層，騎樓，停車場
# 一層，停車場
# 一層，停車場
# 三層，陽台
# 二層，陽台
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台，停車場
# 一層，平台，停車場
# 一層，平台，停車場
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 一層，平台，停車場
# 二層，陽台
# 一層，平台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 四層，陽台
# 一層，停車場
# 一層，停車場
# 二層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 四層，陽台
# 二層，陽台
# 四層，陽台
# 陽台，四層
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 三層，陽台
# 一層，平台
# 陽台，四層
# 四層，陽台
# 陽台，四層
# 一層，平台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 四層，陽台
# 一層，平台，停車場
# 四層，陽台
# 一層，平台
# 三層，陽台
# 五層，陽台
# 五層，陽台
# 一層，騎樓
# 一層，騎樓
# 一層，二層
# 一層，二層，三層，四層，五層
# 二層，陽台
# 一層，騎樓，見其他登記事項
# 一層，二層
# 一層，地下層
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 地下一層，地下二層
# 一層，騎樓
# 一層，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，二層，三層
# 一層，二層，三層
# 一層，二層，三層
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，騎樓，夾層
# 一層，騎樓
# 一層，平台
# 一層，二層，三層，四層，騎樓
# 一層，平台
# 一層，騎樓
# 一層，騎樓
# 一層，騎樓
# 一層，二層，夾層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 夾層，一層
# 一層，夾層
# 一層，平台
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 平台，一層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，二層，見其他登記事項
# 一層，平台，騎樓
# 一層，地下一層
# 一層，騎樓
# 一層，騎樓
# 一層，平台
# 一層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，二層，三層，四層，屋頂突出物
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，二層，三層
# 一層，二層，三層
# 一層，二層，三層，四層，五層，屋頂突出物，地下一層
# 四層，五層，一層，二層，三層，屋頂突出物，地下一層
# 一層，二層，三層，四層，五層，屋頂突出物，地下一層
# 一層，二層
# 一層，二層，三層，四層，五層，地下一層
# 一層，二層，三層，四層，五層，屋頂突出物，地下一層
# 一層，二層，三層，四層，五層，屋頂突出物，地下一層
# 五層，屋頂突出物，地下一層，三層，四層，二層，一層
# 一層，二層
# 一層，二層，三層，四層，五層，屋頂突出物，地下一層
# 一層，二層，三層，四層，屋頂突出物，地下一層，五層
# 一層，二層，三層
# 一層，三層，二層
# 一層，二層，三層
# 一層，二層，三層
# 一層，二層，三層
# 一層，二層，三層
# 一層，二層，三層
# 一層，二層，見其他登記事項
# 一層，二層，見其他登記事項
# 一層，二層，夾層
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，騎樓
# 一層，二層，三層，四層
# 一層，騎樓
# 一層，騎樓
# 二層，陽台
# 三層，陽台
# 三層，陽台
# 四層，陽台
# 四層，陽台
# 一層，騎樓
# 一層，騎樓
# 三層，陽台
# 三層，陽台
# 一層，騎樓
# 一層，二層
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 三層，陽台
# 一層，平台
# 一層，平台
# 三層，陽台
# 四層，陽台
# 二層，陽台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，陽台
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，平台，騎樓
# 一層，夾層
# 一層，夾層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，二層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 一層，平台
# 一層，平台
# 二層，陽台
# 一層，騎樓
# 一層，平台
# 一層，平台
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，見其他登記事項
# 一層，見其他登記事項
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，夾層
# 一層，平台
# 一層，平台
# 一層，騎樓
# 一層，騎樓
# 一層，夾層
# 一層，騎樓
# 一層，夾層
# 一層，夾層
# 一層，夾層
# 一層，平台
# 一層，平台
# 一層，平台
# 一層，地下一層
# 一層，見其他登記事項
# 一層，騎樓
# 一層，騎樓
# 一層，二層
# 一層，騎樓
# 一層，二層，三層，四層，五層
# 一層，二層
# 一層，騎樓
# 二層，三層，四層
# 二層，三層，四層
# 10725

# %%
na.trasaction_floor = na.trasaction_floor.fillna("0")
# Out:
# e:\program\python\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
na = na.reset_index(drop = True)

# %%
na[na.trasaction_floor == '一層，二層，三層，四層，五層']
# Out:
#            id  section  parking_space  construction_time  trade_time  age  \
# 24177  333162       25              0             870318     1030722   16
# 25356  363750       28              0             901105     1050513   14
#
#        unit_price_ping      area trasaction_floor total_floor  ... partition  \
# 24177       84754.1004  53.09502   一層，二層，三層，四層，五層          五層  ...         1
# 25356      168450.3448  52.83480   一層，二層，三層，四層，五層          七層  ...         1
#
#        mgmt   min_inci   min_hos    min_mrt  min_mart   min_gas  min_school  \
# 24177     0  35.168337  0.490439  19.772716  0.291549  0.445791    0.464373
# 25356     0   4.896974  2.278833   8.372294  1.865220  0.692925    0.233799
#
#        min_park  yearMonth
# 24177  0.319748     103-07
# 25356  0.340038     105-05
#
# [2 rows x 25 columns]

# %%
na.iloc[24177,:]
# Out:
# id                           333162
# section                          25
# parking_space                     0
# construction_time            870318
# trade_time                  1030722
# age                              16
# unit_price_ping          84754.1004
# area                       53.09502
# trasaction_floor     一層，二層，三層，四層，五層
# total_floor                      五層
# floor                           NaN
# type                              1
# room                              3
# lr                                2
# bath                              3
# partition                         1
# mgmt                              0
# min_inci                  35.168337
# min_hos                    0.490439
# min_mrt                   19.772716
# min_mart                   0.291549
# min_gas                    0.445791
# min_school                 0.464373
# min_park                   0.319748
# yearMonth                    103-07
# Name: 24177, dtype: object
